# %% [markdown]
# ## Homework Instruction: Stock Trading Simulation
#
# **Objective**: Use the concepts of Python you've learned in the last two lectures to design a simple stock trading algorithm. The goal is to maximize your money by the end of day 100.
#
# ### Description:
#
# 1. **StockMarket Class**:
#    - This class is provisws as-is. DO NOT modify this class.
#    - It has a method named `advance_one_day` which simulates the stock market for one day. If the price of a stock drops below $0.01, you will no longer be able to trade it, and the number of shares of that stock in your portfolio will become 0.
#    - It has a method named `get_stock_prices` which returns the current stock price.
#
# 2. **Portfolio Class**:
#    - This class is provisws as-is. DO NOT modify this class.
#    - **Attributes**:
#      - `cash`: the amount of money you currently have.
#      - `stocks`: number of different stocks you currently own.
#    - **Methods**:
#      - `buy`: purchase k shares of a given stock.
#        - Input: ticker of the stock (`stock_ticker`), number of shares (`k`), the current price of the given stock (`stock_price`).
#        - Deduct cash by `(stock price * k) + 0.50` (50 cents fee for each transaction).
#        - Update stocks attribute.
#      - `sell`: sell k shares of a stock.
#        - Input: ticker of the stock (`stock_ticker`), number of shares (`k`), the current price of the given stock (`stock_price`).
#        - Add to cash by `(stock price * k) - 0.50` (50 cents fee for each transaction).
#        - Update stocks attribute.
#
# 3. **Your Task**:
#    - For each day until day 100:
#      - Use `get_stock_prices` method to get the current stock prices.
#      - Decide whether to buy/sell stocks based on the current stock prices.
#      - Use `advance_one_day` method to move to the next day.
#    - You may write any helper functions you need, as long as you don't change the code of both classes.
#    - Your goal is to have as much money as possible by the end of day 100.
#
# **Steps**:
#
# 1. Initialize the stock market and your portfolio.
# 2. Loop through each day and make buy/sell decisions.
# 3. Use the `advance_one_day` function to progress through the simulation.
# 4. At the end of day 100, compute and print the total value (cash and stock values) of your portfolio.

# %% [markdown]
# ## Skeleton Code:

# %%
import numpy as np
import random
import string

class StockMarket:
    def __init__(self, stock_tickers):
        self.stock_prices = {ticker: np.random.uniform(10, 100) for ticker in stock_tickers}
        self.deltas = {ticker: self.get_new_delta() for ticker in stock_tickers}
        self.days_since_last_change = {ticker: 0 for ticker in stock_tickers}

    def get_new_delta(self):
        return np.random.normal(0, 0.03)

    def advance_one_day(self):
        for ticker in self.stock_prices:
            if self.stock_prices[ticker] < 0.01:
                continue
            chance_of_change = 0.1 + 0.1 * self.days_since_last_change[ticker]
            if np.random.rand() < chance_of_change:
                self.deltas[ticker] = self.get_new_delta()
                self.days_since_last_change[ticker] = 0
            self.stock_prices[ticker] *= (1 + self.deltas[ticker])
            self.days_since_last_change[ticker] += 1

    def get_stock_prices(self):
        return self.stock_prices

class Portfolio:
    def __init__(self, initial_cash):
        self.cash = initial_cash
        self.stocks = {}

    def buy(self, stock_ticker, k, stock_price):
        if stock_price < 0.01:
            self.stocks[stock_ticker] = 0
            return
        total_cost = (stock_price * k) + 0.50
        if self.cash >= total_cost:
            self.cash -= total_cost
            self.stocks[stock_ticker] = self.stocks.get(stock_ticker, 0) + k

    def sell(self, stock_ticker, k, stock_price):
        if stock_price < 0.01:
            self.stocks[stock_ticker] = 0
            return
        if stock_ticker in self.stocks and self.stocks[stock_ticker] >= k:
            self.cash += (stock_price * k) - 0.50
            self.stocks[stock_ticker] -= k
            if self.stocks[stock_ticker] == 0:
                del self.stocks[stock_ticker]

def generate_stock_ticker(length=4):
    """
    randomly generates a stock ticker containing upper case letters and numbers with the given length
    """
    letters = string.ascii_uppercase
    numbers = string.digits
    ticker = ''.join(random.choice(letters + numbers) for _ in range(length))
    return ticker

STOCK_TICKERS = [generate_stock_ticker() for _ in range(6)]
INITIAL_CASH = 1000


def main():
    ## TODO: Replace the following code with your algorithm
    final_value = 0
    
    # initilization
    my_portfolio = Portfolio(INITIAL_CASH)
    stock_market = StockMarket(STOCK_TICKERS)

    # keep track of stock prices
    stock_prices_lst = []

    for day in range(100):
        cur_stock_prices = stock_market.get_stock_prices()
    

        if day == 0:
            # copy dict to avoid using the same reference
            stock_prices_lst.append(cur_stock_prices.copy())
            stock_market.advance_one_day()
            continue

        yes_stock_prices = stock_prices_lst[-1]



        for stock_ticker in cur_stock_prices:
            cur_stock_price = cur_stock_prices[stock_ticker]
            yes_stock_price = yes_stock_prices[stock_ticker]

            delta = (cur_stock_price - yes_stock_price) / yes_stock_price

            if cur_stock_price <= 30 and delta >= 0.02:
                my_portfolio.buy(stock_ticker, 10 , cur_stock_price)
                print(f"Day {day+1} Stock: {stock_ticker} tried operation: Buy")
            elif cur_stock_price >= 70 and delta <= -0.01:
                my_portfolio.sell(stock_ticker, 10, cur_stock_price)
                print(f"Day {day+1} Stock: {stock_ticker} tried operation: Sell")
            else:
                print(f"Day {day+1} Stock: {stock_ticker} tried operation: Nothing")

        stock_prices_lst.append(cur_stock_prices.copy())
        stock_market.advance_one_day()

        final_value = my_portfolio.cash

        for stock_ticker, num_shares in my_portfolio.stocks.items():
            final_value += cur_stock_prices[stock_ticker] * num_shares
        
        print(f"Day {day+1} value: {final_value:.2f}")
        

    print('\n')
    print(f"Total value of portfolio after 100 days: ${final_value:.2f}")

if __name__ == "__main__":
    main()
# Out:
# Day 2 Stock: 5AXZ tried operation: Sell
# Day 2 Stock: WTBP tried operation: Sell
# Day 2 Stock: 7EQY tried operation: Nothing
# Day 2 Stock: GS05 tried operation: Nothing
# Day 2 Stock: X1IK tried operation: Nothing
# Day 2 Stock: P4T2 tried operation: Nothing
# Day 2 value: 1000.00
# Day 3 Stock: 5AXZ tried operation: Sell
# Day 3 Stock: WTBP tried operation: Sell
# Day 3 Stock: 7EQY tried operation: Nothing
# Day 3 Stock: GS05 tried operation: Nothing
# Day 3 Stock: X1IK tried operation: Nothing
# Day 3 Stock: P4T2 tried operation: Nothing
# Day 3 value: 1000.00
# Day 4 Stock: 5AXZ tried operation: Nothing
# Day 4 Stock: WTBP tried operation: Sell
# Day 4 Stock: 7EQY tried operation: Nothing
# Day 4 Stock: GS05 tried operation: Nothing
# Day 4 Stock: X1IK tried operation: Nothing
# Day 4 Stock: P4T2 tried operation: Nothing
# Day 4 value: 1000.00
# Day 5 Stock: 5AXZ tried operation: Nothing
# Day 5 Stock: WTBP tried operation: Nothing
# Day 5 Stock: 7EQY tried operation: Sell
# Day 5 Stock: GS05 tried operation: Nothing
# Day 5 Stock: X1IK tried operation: Nothing
# Day 5 Stock: P4T2 tried operation: Nothing
# Day 5 value: 1000.00
# Day 6 Stock: 5AXZ tried operation: Nothing
# Day 6 Stock: WTBP tried operation: Nothing
# Day 6 Stock: 7EQY tried operation: Sell
# Day 6 Stock: GS05 tried operation: Nothing
# Day 6 Stock: X1IK tried operation: Nothing
# Day 6 Stock: P4T2 tried operation: Nothing
# Day 6 value: 1000.00
# Day 7 Stock: 5AXZ tried operation: Nothing
# Day 7 Stock: WTBP tried operation: Nothing
# Day 7 Stock: 7EQY tried operation: Nothing
# Day 7 Stock: GS05 tried operation: Nothing
# Day 7 Stock: X1IK tried operation: Nothing
# Day 7 Stock: P4T2 tried operation: Nothing
# Day 7 value: 1000.00
# Day 8 Stock: 5AXZ tried operation: Nothing
# Day 8 Stock: WTBP tried operation: Nothing
# Day 8 Stock: 7EQY tried operation: Nothing
# Day 8 Stock: GS05 tried operation: Nothing
# Day 8 Stock: X1IK tried operation: Nothing
# Day 8 Stock: P4T2 tried operation: Nothing
# Day 8 value: 1000.00
# Day 9 Stock: 5AXZ tried operation: Sell
# Day 9 Stock: WTBP tried operation: Nothing
# Day 9 Stock: 7EQY tried operation: Nothing
# Day 9 Stock: GS05 tried operation: Nothing
# Day 9 Stock: X1IK tried operation: Nothing
# Day 9 Stock: P4T2 tried operation: Nothing
# Day 9 value: 1000.00
# Day 10 Stock: 5AXZ tried operation: Sell
# Day 10 Stock: WTBP tried operation: Nothing
# Day 10 Stock: 7EQY tried operation: Nothing
# Day 10 Stock: GS05 tried operation: Nothing
# Day 10 Stock: X1IK tried operation: Nothing
# Day 10 Stock: P4T2 tried operation: Nothing
# Day 10 value: 1000.00
# Day 11 Stock: 5AXZ tried operation: Sell
# Day 11 Stock: WTBP tried operation: Sell
# Day 11 Stock: 7EQY tried operation: Nothing
# Day 11 Stock: GS05 tried operation: Nothing
# Day 11 Stock: X1IK tried operation: Nothing
# Day 11 Stock: P4T2 tried operation: Nothing
# Day 11 value: 1000.00
# Day 12 Stock: 5AXZ tried operation: Sell
# Day 12 Stock: WTBP tried operation: Sell
# Day 12 Stock: 7EQY tried operation: Nothing
# Day 12 Stock: GS05 tried operation: Nothing
# Day 12 Stock: X1IK tried operation: Nothing
# Day 12 Stock: P4T2 tried operation: Nothing
# Day 12 value: 1000.00
# Day 13 Stock: 5AXZ tried operation: Sell
# Day 13 Stock: WTBP tried operation: Sell
# Day 13 Stock: 7EQY tried operation: Nothing
# Day 13 Stock: GS05 tried operation: Nothing
# Day 13 Stock: X1IK tried operation: Nothing
# Day 13 Stock: P4T2 tried operation: Nothing
# Day 13 value: 1000.00
# Day 14 Stock: 5AXZ tried operation: Sell
# Day 14 Stock: WTBP tried operation: Sell
# Day 14 Stock: 7EQY tried operation: Nothing
# Day 14 Stock: GS05 tried operation: Nothing
# Day 14 Stock: X1IK tried operation: Nothing
# Day 14 Stock: P4T2 tried operation: Nothing
# Day 14 value: 1000.00
# Day 15 Stock: 5AXZ tried operation: Sell
# Day 15 Stock: WTBP tried operation: Nothing
# Day 15 Stock: 7EQY tried operation: Nothing
# Day 15 Stock: GS05 tried operation: Nothing
# Day 15 Stock: X1IK tried operation: Nothing
# Day 15 Stock: P4T2 tried operation: Nothing
# Day 15 value: 1000.00
# Day 16 Stock: 5AXZ tried operation: Nothing
# Day 16 Stock: WTBP tried operation: Nothing
# Day 16 Stock: 7EQY tried operation: Nothing
# Day 16 Stock: GS05 tried operation: Nothing
# Day 16 Stock: X1IK tried operation: Nothing
# Day 16 Stock: P4T2 tried operation: Nothing
# Day 16 value: 1000.00
# Day 17 Stock: 5AXZ tried operation: Nothing
# Day 17 Stock: WTBP tried operation: Nothing
# Day 17 Stock: 7EQY tried operation: Nothing
# Day 17 Stock: GS05 tried operation: Nothing
# Day 17 Stock: X1IK tried operation: Nothing
# Day 17 Stock: P4T2 tried operation: Nothing
# Day 17 value: 1000.00
# Day 18 Stock: 5AXZ tried operation: Sell
# Day 18 Stock: WTBP tried operation: Nothing
# Day 18 Stock: 7EQY tried operation: Nothing
# Day 18 Stock: GS05 tried operation: Nothing
# Day 18 Stock: X1IK tried operation: Nothing
# Day 18 Stock: P4T2 tried operation: Nothing
# Day 18 value: 1000.00
# Day 19 Stock: 5AXZ tried operation: Sell
# Day 19 Stock: WTBP tried operation: Nothing
# Day 19 Stock: 7EQY tried operation: Nothing
# Day 19 Stock: GS05 tried operation: Buy
# Day 19 Stock: X1IK tried operation: Nothing
# Day 19 Stock: P4T2 tried operation: Nothing
# Day 19 value: 1006.11
# Day 20 Stock: 5AXZ tried operation: Nothing
# Day 20 Stock: WTBP tried operation: Nothing
# Day 20 Stock: 7EQY tried operation: Sell
# Day 20 Stock: GS05 tried operation: Buy
# Day 20 Stock: X1IK tried operation: Nothing
# Day 20 Stock: P4T2 tried operation: Nothing
# Day 20 value: 1019.23
# Day 21 Stock: 5AXZ tried operation: Nothing
# Day 21 Stock: WTBP tried operation: Nothing
# Day 21 Stock: 7EQY tried operation: Nothing
# Day 21 Stock: GS05 tried operation: Buy
# Day 21 Stock: X1IK tried operation: Nothing
# Day 21 Stock: P4T2 tried operation: Nothing
# Day 21 value: 1039.77
# Day 22 Stock: 5AXZ tried operation: Nothing
# Day 22 Stock: WTBP tried operation: Nothing
# Day 22 Stock: 7EQY tried operation: Nothing
# Day 22 Stock: GS05 tried operation: Buy
# Day 22 Stock: X1IK tried operation: Nothing
# Day 22 Stock: P4T2 tried operation: Nothing
# Day 22 value: 1059.90
# Day 23 Stock: 5AXZ tried operation: Nothing
# Day 23 Stock: WTBP tried operation: Nothing
# Day 23 Stock: 7EQY tried operation: Nothing
# Day 23 Stock: GS05 tried operation: Buy
# Day 23 Stock: X1IK tried operation: Nothing
# Day 23 Stock: P4T2 tried operation: Nothing
# Day 23 value: 1080.97
# Day 24 Stock: 5AXZ tried operation: Nothing
# Day 24 Stock: WTBP tried operation: Nothing
# Day 24 Stock: 7EQY tried operation: Nothing
# Day 24 Stock: GS05 tried operation: Buy
# Day 24 Stock: X1IK tried operation: Nothing
# Day 24 Stock: P4T2 tried operation: Nothing
# Day 24 value: 1102.49
# Day 25 Stock: 5AXZ tried operation: Nothing
# Day 25 Stock: WTBP tried operation: Nothing
# Day 25 Stock: 7EQY tried operation: Nothing
# Day 25 Stock: GS05 tried operation: Buy
# Day 25 Stock: X1IK tried operation: Nothing
# Day 25 Stock: P4T2 tried operation: Nothing
# Day 25 value: 1111.97
# Day 26 Stock: 5AXZ tried operation: Nothing
# Day 26 Stock: WTBP tried operation: Nothing
# Day 26 Stock: 7EQY tried operation: Nothing
# Day 26 Stock: GS05 tried operation: Nothing
# Day 26 Stock: X1IK tried operation: Nothing
# Day 26 Stock: P4T2 tried operation: Nothing
# Day 26 value: 1121.54
# Day 27 Stock: 5AXZ tried operation: Nothing
# Day 27 Stock: WTBP tried operation: Nothing
# Day 27 Stock: 7EQY tried operation: Nothing
# Day 27 Stock: GS05 tried operation: Nothing
# Day 27 Stock: X1IK tried operation: Nothing
# Day 27 Stock: P4T2 tried operation: Nothing
# Day 27 value: 1155.69
# Day 28 Stock: 5AXZ tried operation: Nothing
# Day 28 Stock: WTBP tried operation: Nothing
# Day 28 Stock: 7EQY tried operation: Nothing
# Day 28 Stock: GS05 tried operation: Buy
# Day 28 Stock: X1IK tried operation: Nothing
# Day 28 Stock: P4T2 tried operation: Nothing
# Day 28 value: 1190.96
# Day 29 Stock: 5AXZ tried operation: Nothing
# Day 29 Stock: WTBP tried operation: Sell
# Day 29 Stock: 7EQY tried operation: Nothing
# Day 29 Stock: GS05 tried operation: Buy
# Day 29 Stock: X1IK tried operation: Nothing
# Day 29 Stock: P4T2 tried operation: Nothing
# Day 29 value: 1227.39
# Day 30 Stock: 5AXZ tried operation: Nothing
# Day 30 Stock: WTBP tried operation: Sell
# Day 30 Stock: 7EQY tried operation: Nothing
# Day 30 Stock: GS05 tried operation: Buy
# Day 30 Stock: X1IK tried operation: Nothing
# Day 30 Stock: P4T2 tried operation: Nothing
# Day 30 value: 1239.54
# Day 31 Stock: 5AXZ tried operation: Nothing
# Day 31 Stock: WTBP tried operation: Sell
# Day 31 Stock: 7EQY tried operation: Nothing
# Day 31 Stock: GS05 tried operation: Nothing
# Day 31 Stock: X1IK tried operation: Nothing
# Day 31 Stock: P4T2 tried operation: Nothing
# Day 31 value: 1251.82
# Day 32 Stock: 5AXZ tried operation: Nothing
# Day 32 Stock: WTBP tried operation: Nothing
# Day 32 Stock: 7EQY tried operation: Nothing
# Day 32 Stock: GS05 tried operation: Nothing
# Day 32 Stock: X1IK tried operation: Nothing
# Day 32 Stock: P4T2 tried operation: Nothing
# Day 32 value: 1264.23
# Day 33 Stock: 5AXZ tried operation: Nothing
# Day 33 Stock: WTBP tried operation: Nothing
# Day 33 Stock: 7EQY tried operation: Nothing
# Day 33 Stock: GS05 tried operation: Nothing
# Day 33 Stock: X1IK tried operation: Nothing
# Day 33 Stock: P4T2 tried operation: Nothing
# Day 33 value: 1298.65
# Day 34 Stock: 5AXZ tried operation: Nothing
# Day 34 Stock: WTBP tried operation: Nothing
# Day 34 Stock: 7EQY tried operation: Nothing
# Day 34 Stock: GS05 tried operation: Nothing
# Day 34 Stock: X1IK tried operation: Nothing
# Day 34 Stock: P4T2 tried operation: Nothing
# Day 34 value: 1334.06
# Day 35 Stock: 5AXZ tried operation: Nothing
# Day 35 Stock: WTBP tried operation: Nothing
# Day 35 Stock: 7EQY tried operation: Nothing
# Day 35 Stock: GS05 tried operation: Nothing
# Day 35 Stock: X1IK tried operation: Nothing
# Day 35 Stock: P4T2 tried operation: Nothing
# Day 35 value: 1370.51
# Day 36 Stock: 5AXZ tried operation: Nothing
# Day 36 Stock: WTBP tried operation: Nothing
# Day 36 Stock: 7EQY tried operation: Nothing
# Day 36 Stock: GS05 tried operation: Nothing
# Day 36 Stock: X1IK tried operation: Nothing
# Day 36 Stock: P4T2 tried operation: Nothing
# Day 36 value: 1408.01
# Day 37 Stock: 5AXZ tried operation: Sell
# Day 37 Stock: WTBP tried operation: Nothing
# Day 37 Stock: 7EQY tried operation: Nothing
# Day 37 Stock: GS05 tried operation: Nothing
# Day 37 Stock: X1IK tried operation: Nothing
# Day 37 Stock: P4T2 tried operation: Nothing
# Day 37 value: 1338.01
# Day 38 Stock: 5AXZ tried operation: Nothing
# Day 38 Stock: WTBP tried operation: Nothing
# Day 38 Stock: 7EQY tried operation: Sell
# Day 38 Stock: GS05 tried operation: Nothing
# Day 38 Stock: X1IK tried operation: Nothing
# Day 38 Stock: P4T2 tried operation: Nothing
# Day 38 value: 1271.70
# Day 39 Stock: 5AXZ tried operation: Nothing
# Day 39 Stock: WTBP tried operation: Nothing
# Day 39 Stock: 7EQY tried operation: Sell
# Day 39 Stock: GS05 tried operation: Nothing
# Day 39 Stock: X1IK tried operation: Nothing
# Day 39 Stock: P4T2 tried operation: Nothing
# Day 39 value: 1285.04
# Day 40 Stock: 5AXZ tried operation: Nothing
# Day 40 Stock: WTBP tried operation: Nothing
# Day 40 Stock: 7EQY tried operation: Nothing
# Day 40 Stock: GS05 tried operation: Nothing
# Day 40 Stock: X1IK tried operation: Nothing
# Day 40 Stock: P4T2 tried operation: Nothing
# Day 40 value: 1298.52
# Day 41 Stock: 5AXZ tried operation: Nothing
# Day 41 Stock: WTBP tried operation: Nothing
# Day 41 Stock: 7EQY tried operation: Nothing
# Day 41 Stock: GS05 tried operation: Nothing
# Day 41 Stock: X1IK tried operation: Nothing
# Day 41 Stock: P4T2 tried operation: Nothing
# Day 41 value: 1297.64
# Day 42 Stock: 5AXZ tried operation: Nothing
# Day 42 Stock: WTBP tried operation: Nothing
# Day 42 Stock: 7EQY tried operation: Nothing
# Day 42 Stock: GS05 tried operation: Nothing
# Day 42 Stock: X1IK tried operation: Nothing
# Day 42 Stock: P4T2 tried operation: Nothing
# Day 42 value: 1296.75
# Day 43 Stock: 5AXZ tried operation: Nothing
# Day 43 Stock: WTBP tried operation: Nothing
# Day 43 Stock: 7EQY tried operation: Nothing
# Day 43 Stock: GS05 tried operation: Nothing
# Day 43 Stock: X1IK tried operation: Nothing
# Day 43 Stock: P4T2 tried operation: Nothing
# Day 43 value: 1295.86
# Day 44 Stock: 5AXZ tried operation: Nothing
# Day 44 Stock: WTBP tried operation: Nothing
# Day 44 Stock: 7EQY tried operation: Nothing
# Day 44 Stock: GS05 tried operation: Nothing
# Day 44 Stock: X1IK tried operation: Nothing
# Day 44 Stock: P4T2 tried operation: Nothing
# Day 44 value: 1294.98
# Day 45 Stock: 5AXZ tried operation: Nothing
# Day 45 Stock: WTBP tried operation: Nothing
# Day 45 Stock: 7EQY tried operation: Nothing
# Day 45 Stock: GS05 tried operation: Nothing
# Day 45 Stock: X1IK tried operation: Nothing
# Day 45 Stock: P4T2 tried operation: Nothing
# Day 45 value: 1308.20
# Day 46 Stock: 5AXZ tried operation: Nothing
# Day 46 Stock: WTBP tried operation: Sell
# Day 46 Stock: 7EQY tried operation: Nothing
# Day 46 Stock: GS05 tried operation: Nothing
# Day 46 Stock: X1IK tried operation: Nothing
# Day 46 Stock: P4T2 tried operation: Nothing
# Day 46 value: 1321.57
# Day 47 Stock: 5AXZ tried operation: Nothing
# Day 47 Stock: WTBP tried operation: Sell
# Day 47 Stock: 7EQY tried operation: Nothing
# Day 47 Stock: GS05 tried operation: Nothing
# Day 47 Stock: X1IK tried operation: Nothing
# Day 47 Stock: P4T2 tried operation: Nothing
# Day 47 value: 1335.09
# Day 48 Stock: 5AXZ tried operation: Nothing
# Day 48 Stock: WTBP tried operation: Sell
# Day 48 Stock: 7EQY tried operation: Nothing
# Day 48 Stock: GS05 tried operation: Nothing
# Day 48 Stock: X1IK tried operation: Nothing
# Day 48 Stock: P4T2 tried operation: Nothing
# Day 48 value: 1348.75
# Day 49 Stock: 5AXZ tried operation: Nothing
# Day 49 Stock: WTBP tried operation: Nothing
# Day 49 Stock: 7EQY tried operation: Nothing
# Day 49 Stock: GS05 tried operation: Nothing
# Day 49 Stock: X1IK tried operation: Nothing
# Day 49 Stock: P4T2 tried operation: Nothing
# Day 49 value: 1435.42
# Day 50 Stock: 5AXZ tried operation: Nothing
# Day 50 Stock: WTBP tried operation: Nothing
# Day 50 Stock: 7EQY tried operation: Nothing
# Day 50 Stock: GS05 tried operation: Nothing
# Day 50 Stock: X1IK tried operation: Nothing
# Day 50 Stock: P4T2 tried operation: Nothing
# Day 50 value: 1528.01
# Day 51 Stock: 5AXZ tried operation: Nothing
# Day 51 Stock: WTBP tried operation: Nothing
# Day 51 Stock: 7EQY tried operation: Nothing
# Day 51 Stock: GS05 tried operation: Nothing
# Day 51 Stock: X1IK tried operation: Buy
# Day 51 Stock: P4T2 tried operation: Nothing
# Day 51 value: 1626.91
# Day 52 Stock: 5AXZ tried operation: Nothing
# Day 52 Stock: WTBP tried operation: Sell
# Day 52 Stock: 7EQY tried operation: Nothing
# Day 52 Stock: GS05 tried operation: Nothing
# Day 52 Stock: X1IK tried operation: Buy
# Day 52 Stock: P4T2 tried operation: Nothing
# Day 52 value: 1557.95
# Day 53 Stock: 5AXZ tried operation: Nothing
# Day 53 Stock: WTBP tried operation: Sell
# Day 53 Stock: 7EQY tried operation: Nothing
# Day 53 Stock: GS05 tried operation: Nothing
# Day 53 Stock: X1IK tried operation: Nothing
# Day 53 Stock: P4T2 tried operation: Nothing
# Day 53 value: 1492.06
# Day 54 Stock: 5AXZ tried operation: Nothing
# Day 54 Stock: WTBP tried operation: Sell
# Day 54 Stock: 7EQY tried operation: Nothing
# Day 54 Stock: GS05 tried operation: Nothing
# Day 54 Stock: X1IK tried operation: Nothing
# Day 54 Stock: P4T2 tried operation: Nothing
# Day 54 value: 1537.52
# Day 55 Stock: 5AXZ tried operation: Nothing
# Day 55 Stock: WTBP tried operation: Nothing
# Day 55 Stock: 7EQY tried operation: Sell
# Day 55 Stock: GS05 tried operation: Nothing
# Day 55 Stock: X1IK tried operation: Nothing
# Day 55 Stock: P4T2 tried operation: Nothing
# Day 55 value: 1584.44
# Day 56 Stock: 5AXZ tried operation: Nothing
# Day 56 Stock: WTBP tried operation: Nothing
# Day 56 Stock: 7EQY tried operation: Sell
# Day 56 Stock: GS05 tried operation: Nothing
# Day 56 Stock: X1IK tried operation: Nothing
# Day 56 Stock: P4T2 tried operation: Nothing
# Day 56 value: 1632.87
# Day 57 Stock: 5AXZ tried operation: Nothing
# Day 57 Stock: WTBP tried operation: Nothing
# Day 57 Stock: 7EQY tried operation: Sell
# Day 57 Stock: GS05 tried operation: Nothing
# Day 57 Stock: X1IK tried operation: Nothing
# Day 57 Stock: P4T2 tried operation: Nothing
# Day 57 value: 1682.86
# Day 58 Stock: 5AXZ tried operation: Nothing
# Day 58 Stock: WTBP tried operation: Nothing
# Day 58 Stock: 7EQY tried operation: Nothing
# Day 58 Stock: GS05 tried operation: Nothing
# Day 58 Stock: X1IK tried operation: Nothing
# Day 58 Stock: P4T2 tried operation: Nothing
# Day 58 value: 1734.46
# Day 59 Stock: 5AXZ tried operation: Nothing
# Day 59 Stock: WTBP tried operation: Sell
# Day 59 Stock: 7EQY tried operation: Nothing
# Day 59 Stock: GS05 tried operation: Nothing
# Day 59 Stock: X1IK tried operation: Nothing
# Day 59 Stock: P4T2 tried operation: Nothing
# Day 59 value: 1749.14
# Day 60 Stock: 5AXZ tried operation: Nothing
# Day 60 Stock: WTBP tried operation: Sell
# Day 60 Stock: 7EQY tried operation: Nothing
# Day 60 Stock: GS05 tried operation: Nothing
# Day 60 Stock: X1IK tried operation: Nothing
# Day 60 Stock: P4T2 tried operation: Nothing
# Day 60 value: 1797.29
# Day 61 Stock: 5AXZ tried operation: Nothing
# Day 61 Stock: WTBP tried operation: Sell
# Day 61 Stock: 7EQY tried operation: Nothing
# Day 61 Stock: GS05 tried operation: Nothing
# Day 61 Stock: X1IK tried operation: Nothing
# Day 61 Stock: P4T2 tried operation: Nothing
# Day 61 value: 1846.83
# Day 62 Stock: 5AXZ tried operation: Nothing
# Day 62 Stock: WTBP tried operation: Sell
# Day 62 Stock: 7EQY tried operation: Nothing
# Day 62 Stock: GS05 tried operation: Nothing
# Day 62 Stock: X1IK tried operation: Nothing
# Day 62 Stock: P4T2 tried operation: Nothing
# Day 62 value: 1897.79
# Day 63 Stock: 5AXZ tried operation: Nothing
# Day 63 Stock: WTBP tried operation: Sell
# Day 63 Stock: 7EQY tried operation: Nothing
# Day 63 Stock: GS05 tried operation: Nothing
# Day 63 Stock: X1IK tried operation: Nothing
# Day 63 Stock: P4T2 tried operation: Nothing
# Day 63 value: 1950.22
# Day 64 Stock: 5AXZ tried operation: Nothing
# Day 64 Stock: WTBP tried operation: Sell
# Day 64 Stock: 7EQY tried operation: Nothing
# Day 64 Stock: GS05 tried operation: Nothing
# Day 64 Stock: X1IK tried operation: Nothing
# Day 64 Stock: P4T2 tried operation: Buy
# Day 64 value: 2004.16
# Day 65 Stock: 5AXZ tried operation: Nothing
# Day 65 Stock: WTBP tried operation: Nothing
# Day 65 Stock: 7EQY tried operation: Nothing
# Day 65 Stock: GS05 tried operation: Nothing
# Day 65 Stock: X1IK tried operation: Nothing
# Day 65 Stock: P4T2 tried operation: Buy
# Day 65 value: 2052.04
# Day 66 Stock: 5AXZ tried operation: Nothing
# Day 66 Stock: WTBP tried operation: Nothing
# Day 66 Stock: 7EQY tried operation: Nothing
# Day 66 Stock: GS05 tried operation: Nothing
# Day 66 Stock: X1IK tried operation: Nothing
# Day 66 Stock: P4T2 tried operation: Nothing
# Day 66 value: 2101.12
# Day 67 Stock: 5AXZ tried operation: Nothing
# Day 67 Stock: WTBP tried operation: Nothing
# Day 67 Stock: 7EQY tried operation: Nothing
# Day 67 Stock: GS05 tried operation: Nothing
# Day 67 Stock: X1IK tried operation: Nothing
# Day 67 Stock: P4T2 tried operation: Nothing
# Day 67 value: 2054.68
# Day 68 Stock: 5AXZ tried operation: Nothing
# Day 68 Stock: WTBP tried operation: Sell
# Day 68 Stock: 7EQY tried operation: Nothing
# Day 68 Stock: GS05 tried operation: Nothing
# Day 68 Stock: X1IK tried operation: Nothing
# Day 68 Stock: P4T2 tried operation: Nothing
# Day 68 value: 2009.30
# Day 69 Stock: 5AXZ tried operation: Nothing
# Day 69 Stock: WTBP tried operation: Sell
# Day 69 Stock: 7EQY tried operation: Nothing
# Day 69 Stock: GS05 tried operation: Nothing
# Day 69 Stock: X1IK tried operation: Buy
# Day 69 Stock: P4T2 tried operation: Nothing
# Day 69 value: 2016.03
# Day 70 Stock: 5AXZ tried operation: Nothing
# Day 70 Stock: WTBP tried operation: Sell
# Day 70 Stock: 7EQY tried operation: Nothing
# Day 70 Stock: GS05 tried operation: Nothing
# Day 70 Stock: X1IK tried operation: Buy
# Day 70 Stock: P4T2 tried operation: Nothing
# Day 70 value: 2022.78
# Day 71 Stock: 5AXZ tried operation: Nothing
# Day 71 Stock: WTBP tried operation: Nothing
# Day 71 Stock: 7EQY tried operation: Nothing
# Day 71 Stock: GS05 tried operation: Nothing
# Day 71 Stock: X1IK tried operation: Buy
# Day 71 Stock: P4T2 tried operation: Nothing
# Day 71 value: 2029.56
# Day 72 Stock: 5AXZ tried operation: Nothing
# Day 72 Stock: WTBP tried operation: Sell
# Day 72 Stock: 7EQY tried operation: Nothing
# Day 72 Stock: GS05 tried operation: Nothing
# Day 72 Stock: X1IK tried operation: Buy
# Day 72 Stock: P4T2 tried operation: Nothing
# Day 72 value: 2091.19
# Day 73 Stock: 5AXZ tried operation: Nothing
# Day 73 Stock: WTBP tried operation: Sell
# Day 73 Stock: 7EQY tried operation: Nothing
# Day 73 Stock: GS05 tried operation: Nothing
# Day 73 Stock: X1IK tried operation: Buy
# Day 73 Stock: P4T2 tried operation: Nothing
# Day 73 value: 2154.77
# Day 74 Stock: 5AXZ tried operation: Nothing
# Day 74 Stock: WTBP tried operation: Sell
# Day 74 Stock: 7EQY tried operation: Nothing
# Day 74 Stock: GS05 tried operation: Nothing
# Day 74 Stock: X1IK tried operation: Buy
# Day 74 Stock: P4T2 tried operation: Nothing
# Day 74 value: 2220.35
# Day 75 Stock: 5AXZ tried operation: Nothing
# Day 75 Stock: WTBP tried operation: Sell
# Day 75 Stock: 7EQY tried operation: Nothing
# Day 75 Stock: GS05 tried operation: Nothing
# Day 75 Stock: X1IK tried operation: Buy
# Day 75 Stock: P4T2 tried operation: Nothing
# Day 75 value: 2288.01
# Day 76 Stock: 5AXZ tried operation: Nothing
# Day 76 Stock: WTBP tried operation: Sell
# Day 76 Stock: 7EQY tried operation: Nothing
# Day 76 Stock: GS05 tried operation: Nothing
# Day 76 Stock: X1IK tried operation: Buy
# Day 76 Stock: P4T2 tried operation: Nothing
# Day 76 value: 2235.35
# Day 77 Stock: 5AXZ tried operation: Nothing
# Day 77 Stock: WTBP tried operation: Sell
# Day 77 Stock: 7EQY tried operation: Nothing
# Day 77 Stock: GS05 tried operation: Nothing
# Day 77 Stock: X1IK tried operation: Buy
# Day 77 Stock: P4T2 tried operation: Nothing
# Day 77 value: 2183.94
# Day 78 Stock: 5AXZ tried operation: Nothing
# Day 78 Stock: WTBP tried operation: Sell
# Day 78 Stock: 7EQY tried operation: Nothing
# Day 78 Stock: GS05 tried operation: Nothing
# Day 78 Stock: X1IK tried operation: Buy
# Day 78 Stock: P4T2 tried operation: Nothing
# Day 78 value: 2146.41
# Day 79 Stock: 5AXZ tried operation: Nothing
# Day 79 Stock: WTBP tried operation: Sell
# Day 79 Stock: 7EQY tried operation: Nothing
# Day 79 Stock: GS05 tried operation: Nothing
# Day 79 Stock: X1IK tried operation: Buy
# Day 79 Stock: P4T2 tried operation: Nothing
# Day 79 value: 2109.54
# Day 80 Stock: 5AXZ tried operation: Nothing
# Day 80 Stock: WTBP tried operation: Sell
# Day 80 Stock: 7EQY tried operation: Nothing
# Day 80 Stock: GS05 tried operation: Nothing
# Day 80 Stock: X1IK tried operation: Buy
# Day 80 Stock: P4T2 tried operation: Nothing
# Day 80 value: 2073.33
# Day 81 Stock: 5AXZ tried operation: Nothing
# Day 81 Stock: WTBP tried operation: Sell
# Day 81 Stock: 7EQY tried operation: Nothing
# Day 81 Stock: GS05 tried operation: Nothing
# Day 81 Stock: X1IK tried operation: Buy
# Day 81 Stock: P4T2 tried operation: Nothing
# Day 81 value: 2037.77
# Day 82 Stock: 5AXZ tried operation: Nothing
# Day 82 Stock: WTBP tried operation: Sell
# Day 82 Stock: 7EQY tried operation: Nothing
# Day 82 Stock: GS05 tried operation: Nothing
# Day 82 Stock: X1IK tried operation: Buy
# Day 82 Stock: P4T2 tried operation: Nothing
# Day 82 value: 2038.38
# Day 83 Stock: 5AXZ tried operation: Nothing
# Day 83 Stock: WTBP tried operation: Sell
# Day 83 Stock: 7EQY tried operation: Nothing
# Day 83 Stock: GS05 tried operation: Nothing
# Day 83 Stock: X1IK tried operation: Buy
# Day 83 Stock: P4T2 tried operation: Nothing
# Day 83 value: 1991.96
# Day 84 Stock: 5AXZ tried operation: Nothing
# Day 84 Stock: WTBP tried operation: Sell
# Day 84 Stock: 7EQY tried operation: Nothing
# Day 84 Stock: GS05 tried operation: Nothing
# Day 84 Stock: X1IK tried operation: Nothing
# Day 84 Stock: P4T2 tried operation: Nothing
# Day 84 value: 1959.67
# Day 85 Stock: 5AXZ tried operation: Nothing
# Day 85 Stock: WTBP tried operation: Sell
# Day 85 Stock: 7EQY tried operation: Sell
# Day 85 Stock: GS05 tried operation: Nothing
# Day 85 Stock: X1IK tried operation: Nothing
# Day 85 Stock: P4T2 tried operation: Nothing
# Day 85 value: 1998.72
# Day 86 Stock: 5AXZ tried operation: Nothing
# Day 86 Stock: WTBP tried operation: Sell
# Day 86 Stock: 7EQY tried operation: Nothing
# Day 86 Stock: GS05 tried operation: Nothing
# Day 86 Stock: X1IK tried operation: Nothing
# Day 86 Stock: P4T2 tried operation: Nothing
# Day 86 value: 2038.59
# Day 87 Stock: 5AXZ tried operation: Nothing
# Day 87 Stock: WTBP tried operation: Sell
# Day 87 Stock: 7EQY tried operation: Nothing
# Day 87 Stock: GS05 tried operation: Nothing
# Day 87 Stock: X1IK tried operation: Nothing
# Day 87 Stock: P4T2 tried operation: Nothing
# Day 87 value: 2015.73
# Day 88 Stock: 5AXZ tried operation: Nothing
# Day 88 Stock: WTBP tried operation: Nothing
# Day 88 Stock: 7EQY tried operation: Nothing
# Day 88 Stock: GS05 tried operation: Nothing
# Day 88 Stock: X1IK tried operation: Nothing
# Day 88 Stock: P4T2 tried operation: Nothing
# Day 88 value: 1993.14
# Day 89 Stock: 5AXZ tried operation: Nothing
# Day 89 Stock: WTBP tried operation: Nothing
# Day 89 Stock: 7EQY tried operation: Nothing
# Day 89 Stock: GS05 tried operation: Nothing
# Day 89 Stock: X1IK tried operation: Nothing
# Day 89 Stock: P4T2 tried operation: Nothing
# Day 89 value: 2012.27
# Day 90 Stock: 5AXZ tried operation: Nothing
# Day 90 Stock: WTBP tried operation: Nothing
# Day 90 Stock: 7EQY tried operation: Nothing
# Day 90 Stock: GS05 tried operation: Nothing
# Day 90 Stock: X1IK tried operation: Nothing
# Day 90 Stock: P4T2 tried operation: Nothing
# Day 90 value: 2031.58
# Day 91 Stock: 5AXZ tried operation: Nothing
# Day 91 Stock: WTBP tried operation: Nothing
# Day 91 Stock: 7EQY tried operation: Nothing
# Day 91 Stock: GS05 tried operation: Nothing
# Day 91 Stock: X1IK tried operation: Nothing
# Day 91 Stock: P4T2 tried operation: Nothing
# Day 91 value: 2051.09
# Day 92 Stock: 5AXZ tried operation: Nothing
# Day 92 Stock: WTBP tried operation: Nothing
# Day 92 Stock: 7EQY tried operation: Nothing
# Day 92 Stock: GS05 tried operation: Nothing
# Day 92 Stock: X1IK tried operation: Nothing
# Day 92 Stock: P4T2 tried operation: Nothing
# Day 92 value: 2076.42
# Day 93 Stock: 5AXZ tried operation: Nothing
# Day 93 Stock: WTBP tried operation: Nothing
# Day 93 Stock: 7EQY tried operation: Sell
# Day 93 Stock: GS05 tried operation: Nothing
# Day 93 Stock: X1IK tried operation: Nothing
# Day 93 Stock: P4T2 tried operation: Nothing
# Day 93 value: 2102.08
# Day 94 Stock: 5AXZ tried operation: Sell
# Day 94 Stock: WTBP tried operation: Nothing
# Day 94 Stock: 7EQY tried operation: Sell
# Day 94 Stock: GS05 tried operation: Nothing
# Day 94 Stock: X1IK tried operation: Nothing
# Day 94 Stock: P4T2 tried operation: Nothing
# Day 94 value: 2128.07
# Day 95 Stock: 5AXZ tried operation: Sell
# Day 95 Stock: WTBP tried operation: Nothing
# Day 95 Stock: 7EQY tried operation: Sell
# Day 95 Stock: GS05 tried operation: Nothing
# Day 95 Stock: X1IK tried operation: Buy
# Day 95 Stock: P4T2 tried operation: Nothing
# Day 95 value: 2154.39
# Day 96 Stock: 5AXZ tried operation: Nothing
# Day 96 Stock: WTBP tried operation: Nothing
# Day 96 Stock: 7EQY tried operation: Sell
# Day 96 Stock: GS05 tried operation: Nothing
# Day 96 Stock: X1IK tried operation: Buy
# Day 96 Stock: P4T2 tried operation: Nothing
# Day 96 value: 2187.26
# Day 97 Stock: 5AXZ tried operation: Nothing
# Day 97 Stock: WTBP tried operation: Nothing
# Day 97 Stock: 7EQY tried operation: Sell
# Day 97 Stock: GS05 tried operation: Nothing
# Day 97 Stock: X1IK tried operation: Buy
# Day 97 Stock: P4T2 tried operation: Nothing
# Day 97 value: 2220.65
# Day 98 Stock: 5AXZ tried operation: Nothing
# Day 98 Stock: WTBP tried operation: Nothing
# Day 98 Stock: 7EQY tried operation: Sell
# Day 98 Stock: GS05 tried operation: Nothing
# Day 98 Stock: X1IK tried operation: Nothing
# Day 98 Stock: P4T2 tried operation: Nothing
# Day 98 value: 2254.57
# Day 99 Stock: 5AXZ tried operation: Nothing
# Day 99 Stock: WTBP tried operation: Nothing
# Day 99 Stock: 7EQY tried operation: Sell
# Day 99 Stock: GS05 tried operation: Nothing
# Day 99 Stock: X1IK tried operation: Nothing
# Day 99 Stock: P4T2 tried operation: Nothing
# Day 99 value: 2289.02
# Day 100 Stock: 5AXZ tried operation: Nothing
# Day 100 Stock: WTBP tried operation: Nothing
# Day 100 Stock: 7EQY tried operation: Sell
# Day 100 Stock: GS05 tried operation: Nothing
# Day 100 Stock: X1IK tried operation: Nothing
# Day 100 Stock: P4T2 tried operation: Nothing
# Day 100 value: 2324.02
#
#
# Total value of portfolio after 100 days: $2324.02

# %% [markdown]
# ## Sample Solution
