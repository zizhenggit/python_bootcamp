# %% [markdown]
# ## Homework Instruction: Stock Trading Simulation
#
# **Objective**: Use the concepts of Python you've learned in the last two lectures to design a simple stock trading algorithm. The goal is to maximize your money by the end of day 100.
#
# ### Description:
#
# 1. **StockMarket Class**:
#    - This class is provisws as-is. DO NOT modify this class.
#    - It has a method named `advance_one_day` which simulates the stock market for one day. If the price of a stock drops below $0.01, you will no longer be able to trade it, and the number of shares of that stock in your portfolio will become 0.
#    - It has a method named `get_stock_prices` which returns the current stock price.
#
# 2. **Portfolio Class**:
#    - This class is provisws as-is. DO NOT modify this class.
#    - **Attributes**:
#      - `cash`: the amount of money you currently have.
#      - `stocks`: number of different stocks you currently own.
#    - **Methods**:
#      - `buy`: purchase k shares of a given stock.
#        - Input: ticker of the stock (`stock_ticker`), number of shares (`k`), the current price of the given stock (`stock_price`).
#        - Deduct cash by `(stock price * k) + 0.50` (50 cents fee for each transaction).
#        - Update stocks attribute.
#      - `sell`: sell k shares of a stock.
#        - Input: ticker of the stock (`stock_ticker`), number of shares (`k`), the current price of the given stock (`stock_price`).
#        - Add to cash by `(stock price * k) - 0.50` (50 cents fee for each transaction).
#        - Update stocks attribute.
#
# 3. **Your Task**:
#    - For each day until day 100:
#      - Use `get_stock_prices` method to get the current stock prices.
#      - Decide whether to buy/sell stocks based on the current stock prices.
#      - Use `advance_one_day` method to move to the next day.
#    - You may write any helper functions you need, as long as you don't change the code of both classes.
#    - Your goal is to have as much money as possible by the end of day 100.
#
# **Steps**:
#
# 1. Initialize the stock market and your portfolio.
# 2. Loop through each day and make buy/sell decisions.
# 3. Use the `advance_one_day` function to progress through the simulation.
# 4. At the end of day 100, compute and print the total value (cash and stock values) of your portfolio.

# %% [markdown]
# ## Skeleton Code:

# %%
import numpy as np
import random
import string

class StockMarket:
    def __init__(self, stock_tickers):
        self.stock_prices = {ticker: np.random.uniform(10, 100) for ticker in stock_tickers}
        self.deltas = {ticker: self.get_new_delta() for ticker in stock_tickers}
        self.days_since_last_change = {ticker: 0 for ticker in stock_tickers}

    def get_new_delta(self):
        return np.random.normal(0, 0.03)

    def advance_one_day(self):
        for ticker in self.stock_prices:
            if self.stock_prices[ticker] < 0.01:
                continue
            chance_of_change = 0.1 + 0.1 * self.days_since_last_change[ticker]
            if np.random.rand() < chance_of_change:
                self.deltas[ticker] = self.get_new_delta()
                self.days_since_last_change[ticker] = 0
            self.stock_prices[ticker] *= (1 + self.deltas[ticker])
            self.days_since_last_change[ticker] += 1

    def get_stock_prices(self):
        return self.stock_prices

class Portfolio:
    def __init__(self, initial_cash):
        self.cash = initial_cash
        self.stocks = {}

    def buy(self, stock_ticker, k, stock_price):
        if stock_price < 0.01:
            self.stocks[stock_ticker] = 0
            return
        total_cost = (stock_price * k) + 0.50
        if self.cash >= total_cost:
            self.cash -= total_cost
            self.stocks[stock_ticker] = self.stocks.get(stock_ticker, 0) + k

    def sell(self, stock_ticker, k, stock_price):
        if stock_price < 0.01:
            self.stocks[stock_ticker] = 0
            return
        if stock_ticker in self.stocks and self.stocks[stock_ticker] >= k:
            self.cash += (stock_price * k) - 0.50
            self.stocks[stock_ticker] -= k
            if self.stocks[stock_ticker] == 0:
                del self.stocks[stock_ticker]

def generate_stock_ticker(length=4):
    """
    randomly generates a stock ticker containing upper case letters and numbers with the given length
    """
    letters = string.ascii_uppercase
    numbers = string.digits
    ticker = ''.join(random.choice(letters + numbers) for _ in range(length))
    return ticker

STOCK_TICKERS = [generate_stock_ticker() for _ in range(6)]
INITIAL_CASH = 1000


def main():
    ## TODO: Replace the following code with your algorithm
    final_value = 0
    
    # initilization
    my_portfolio = Portfolio(INITIAL_CASH)
    stock_market = StockMarket(STOCK_TICKERS)

    # keep track of stock prices
    stock_prices_lst = []

    for day in range(100):
        cur_stock_prices = stock_market.get_stock_prices()
    

        if day == 0:
            # copy dict to avoid using the same reference
            stock_prices_lst.append(cur_stock_prices.copy())
            stock_market.advance_one_day()
            continue

        yes_stock_prices = stock_prices_lst[-1]



        for stock_ticker in cur_stock_prices:
            cur_stock_price = cur_stock_prices[stock_ticker]
            yes_stock_price = yes_stock_prices[stock_ticker]

            delta = (cur_stock_price - yes_stock_price) / yes_stock_price

            if cur_stock_price <= 30 and delta >= 0.02:
                my_portfolio.buy(stock_ticker, 10 , cur_stock_price)
                print(f"Day {day+1} Stock: {stock_ticker} tried operation: Buy")
            elif cur_stock_price >= 70 and delta <= -0.01:
                my_portfolio.sell(stock_ticker, 10, cur_stock_price)
                print(f"Day {day+1} Stock: {stock_ticker} tried operation: Sell")
            else:
                print(f"Day {day+1} Stock: {stock_ticker} tried operation: Nothing")

        stock_prices_lst.append(cur_stock_prices.copy())
        stock_market.advance_one_day()

        final_value = my_portfolio.cash

        for stock_ticker, num_shares in my_portfolio.stocks.items():
            final_value += cur_stock_prices[stock_ticker] * num_shares
        
        print(f"Day {day+1} value: {final_value:.2f}")
        

    print('\n')
    print(f"Total value of portfolio after 100 days: ${final_value:.2f}")

if __name__ == "__main__":
    main()
# Out:
# Day 2 Stock: ZPVX tried operation: Nothing
# Day 2 Stock: EJ0Y tried operation: Nothing
# Day 2 Stock: JHO0 tried operation: Nothing
# Day 2 Stock: KCYU tried operation: Nothing
# Day 2 Stock: TTVQ tried operation: Nothing
# Day 2 Stock: Y5NS tried operation: Nothing
# Day 2 value: 1000.00
# Day 3 Stock: ZPVX tried operation: Buy
# Day 3 Stock: EJ0Y tried operation: Nothing
# Day 3 Stock: JHO0 tried operation: Nothing
# Day 3 Stock: KCYU tried operation: Nothing
# Day 3 Stock: TTVQ tried operation: Nothing
# Day 3 Stock: Y5NS tried operation: Nothing
# Day 3 value: 1002.03
# Day 4 Stock: ZPVX tried operation: Buy
# Day 4 Stock: EJ0Y tried operation: Nothing
# Day 4 Stock: JHO0 tried operation: Nothing
# Day 4 Stock: KCYU tried operation: Nothing
# Day 4 Stock: TTVQ tried operation: Nothing
# Day 4 Stock: Y5NS tried operation: Nothing
# Day 4 value: 1006.71
# Day 5 Stock: ZPVX tried operation: Buy
# Day 5 Stock: EJ0Y tried operation: Nothing
# Day 5 Stock: JHO0 tried operation: Nothing
# Day 5 Stock: KCYU tried operation: Nothing
# Day 5 Stock: TTVQ tried operation: Nothing
# Day 5 Stock: Y5NS tried operation: Nothing
# Day 5 value: 1025.11
# Day 6 Stock: ZPVX tried operation: Buy
# Day 6 Stock: EJ0Y tried operation: Nothing
# Day 6 Stock: JHO0 tried operation: Nothing
# Day 6 Stock: KCYU tried operation: Nothing
# Day 6 Stock: TTVQ tried operation: Nothing
# Day 6 Stock: Y5NS tried operation: Sell
# Day 6 value: 1039.45
# Day 7 Stock: ZPVX tried operation: Buy
# Day 7 Stock: EJ0Y tried operation: Nothing
# Day 7 Stock: JHO0 tried operation: Nothing
# Day 7 Stock: KCYU tried operation: Nothing
# Day 7 Stock: TTVQ tried operation: Nothing
# Day 7 Stock: Y5NS tried operation: Sell
# Day 7 value: 1058.05
# Day 8 Stock: ZPVX tried operation: Buy
# Day 8 Stock: EJ0Y tried operation: Nothing
# Day 8 Stock: JHO0 tried operation: Nothing
# Day 8 Stock: KCYU tried operation: Nothing
# Day 8 Stock: TTVQ tried operation: Nothing
# Day 8 Stock: Y5NS tried operation: Sell
# Day 8 value: 1081.15
# Day 9 Stock: ZPVX tried operation: Buy
# Day 9 Stock: EJ0Y tried operation: Nothing
# Day 9 Stock: JHO0 tried operation: Nothing
# Day 9 Stock: KCYU tried operation: Nothing
# Day 9 Stock: TTVQ tried operation: Nothing
# Day 9 Stock: Y5NS tried operation: Sell
# Day 9 value: 1108.99
# Day 10 Stock: ZPVX tried operation: Buy
# Day 10 Stock: EJ0Y tried operation: Nothing
# Day 10 Stock: JHO0 tried operation: Nothing
# Day 10 Stock: KCYU tried operation: Nothing
# Day 10 Stock: TTVQ tried operation: Nothing
# Day 10 Stock: Y5NS tried operation: Nothing
# Day 10 value: 1068.63
# Day 11 Stock: ZPVX tried operation: Nothing
# Day 11 Stock: EJ0Y tried operation: Nothing
# Day 11 Stock: JHO0 tried operation: Nothing
# Day 11 Stock: KCYU tried operation: Nothing
# Day 11 Stock: TTVQ tried operation: Sell
# Day 11 Stock: Y5NS tried operation: Nothing
# Day 11 value: 1029.93
# Day 12 Stock: ZPVX tried operation: Nothing
# Day 12 Stock: EJ0Y tried operation: Nothing
# Day 12 Stock: JHO0 tried operation: Nothing
# Day 12 Stock: KCYU tried operation: Nothing
# Day 12 Stock: TTVQ tried operation: Nothing
# Day 12 Stock: Y5NS tried operation: Nothing
# Day 12 value: 992.81
# Day 13 Stock: ZPVX tried operation: Nothing
# Day 13 Stock: EJ0Y tried operation: Nothing
# Day 13 Stock: JHO0 tried operation: Nothing
# Day 13 Stock: KCYU tried operation: Nothing
# Day 13 Stock: TTVQ tried operation: Nothing
# Day 13 Stock: Y5NS tried operation: Nothing
# Day 13 value: 957.20
# Day 14 Stock: ZPVX tried operation: Nothing
# Day 14 Stock: EJ0Y tried operation: Nothing
# Day 14 Stock: JHO0 tried operation: Nothing
# Day 14 Stock: KCYU tried operation: Nothing
# Day 14 Stock: TTVQ tried operation: Nothing
# Day 14 Stock: Y5NS tried operation: Nothing
# Day 14 value: 923.06
# Day 15 Stock: ZPVX tried operation: Nothing
# Day 15 Stock: EJ0Y tried operation: Nothing
# Day 15 Stock: JHO0 tried operation: Buy
# Day 15 Stock: KCYU tried operation: Nothing
# Day 15 Stock: TTVQ tried operation: Nothing
# Day 15 Stock: Y5NS tried operation: Nothing
# Day 15 value: 921.94
# Day 16 Stock: ZPVX tried operation: Nothing
# Day 16 Stock: EJ0Y tried operation: Nothing
# Day 16 Stock: JHO0 tried operation: Buy
# Day 16 Stock: KCYU tried operation: Nothing
# Day 16 Stock: TTVQ tried operation: Nothing
# Day 16 Stock: Y5NS tried operation: Nothing
# Day 16 value: 920.81
# Day 17 Stock: ZPVX tried operation: Nothing
# Day 17 Stock: EJ0Y tried operation: Nothing
# Day 17 Stock: JHO0 tried operation: Buy
# Day 17 Stock: KCYU tried operation: Nothing
# Day 17 Stock: TTVQ tried operation: Nothing
# Day 17 Stock: Y5NS tried operation: Nothing
# Day 17 value: 919.70
# Day 18 Stock: ZPVX tried operation: Nothing
# Day 18 Stock: EJ0Y tried operation: Nothing
# Day 18 Stock: JHO0 tried operation: Buy
# Day 18 Stock: KCYU tried operation: Nothing
# Day 18 Stock: TTVQ tried operation: Nothing
# Day 18 Stock: Y5NS tried operation: Nothing
# Day 18 value: 918.58
# Day 19 Stock: ZPVX tried operation: Nothing
# Day 19 Stock: EJ0Y tried operation: Nothing
# Day 19 Stock: JHO0 tried operation: Buy
# Day 19 Stock: KCYU tried operation: Nothing
# Day 19 Stock: TTVQ tried operation: Nothing
# Day 19 Stock: Y5NS tried operation: Nothing
# Day 19 value: 942.07
# Day 20 Stock: ZPVX tried operation: Buy
# Day 20 Stock: EJ0Y tried operation: Nothing
# Day 20 Stock: JHO0 tried operation: Buy
# Day 20 Stock: KCYU tried operation: Nothing
# Day 20 Stock: TTVQ tried operation: Nothing
# Day 20 Stock: Y5NS tried operation: Nothing
# Day 20 value: 999.56
# Day 21 Stock: ZPVX tried operation: Buy
# Day 21 Stock: EJ0Y tried operation: Nothing
# Day 21 Stock: JHO0 tried operation: Nothing
# Day 21 Stock: KCYU tried operation: Nothing
# Day 21 Stock: TTVQ tried operation: Nothing
# Day 21 Stock: Y5NS tried operation: Nothing
# Day 21 value: 1025.23
# Day 22 Stock: ZPVX tried operation: Buy
# Day 22 Stock: EJ0Y tried operation: Nothing
# Day 22 Stock: JHO0 tried operation: Nothing
# Day 22 Stock: KCYU tried operation: Nothing
# Day 22 Stock: TTVQ tried operation: Nothing
# Day 22 Stock: Y5NS tried operation: Sell
# Day 22 value: 1051.55
# Day 23 Stock: ZPVX tried operation: Buy
# Day 23 Stock: EJ0Y tried operation: Nothing
# Day 23 Stock: JHO0 tried operation: Nothing
# Day 23 Stock: KCYU tried operation: Nothing
# Day 23 Stock: TTVQ tried operation: Nothing
# Day 23 Stock: Y5NS tried operation: Sell
# Day 23 value: 1078.56
# Day 24 Stock: ZPVX tried operation: Buy
# Day 24 Stock: EJ0Y tried operation: Nothing
# Day 24 Stock: JHO0 tried operation: Nothing
# Day 24 Stock: KCYU tried operation: Nothing
# Day 24 Stock: TTVQ tried operation: Nothing
# Day 24 Stock: Y5NS tried operation: Sell
# Day 24 value: 1106.26
# Day 25 Stock: ZPVX tried operation: Buy
# Day 25 Stock: EJ0Y tried operation: Nothing
# Day 25 Stock: JHO0 tried operation: Nothing
# Day 25 Stock: KCYU tried operation: Nothing
# Day 25 Stock: TTVQ tried operation: Nothing
# Day 25 Stock: Y5NS tried operation: Sell
# Day 25 value: 1073.29
# Day 26 Stock: ZPVX tried operation: Nothing
# Day 26 Stock: EJ0Y tried operation: Nothing
# Day 26 Stock: JHO0 tried operation: Nothing
# Day 26 Stock: KCYU tried operation: Nothing
# Day 26 Stock: TTVQ tried operation: Nothing
# Day 26 Stock: Y5NS tried operation: Nothing
# Day 26 value: 1136.64
# Day 27 Stock: ZPVX tried operation: Buy
# Day 27 Stock: EJ0Y tried operation: Nothing
# Day 27 Stock: JHO0 tried operation: Nothing
# Day 27 Stock: KCYU tried operation: Nothing
# Day 27 Stock: TTVQ tried operation: Nothing
# Day 27 Stock: Y5NS tried operation: Nothing
# Day 27 value: 1203.75
# Day 28 Stock: ZPVX tried operation: Buy
# Day 28 Stock: EJ0Y tried operation: Nothing
# Day 28 Stock: JHO0 tried operation: Buy
# Day 28 Stock: KCYU tried operation: Nothing
# Day 28 Stock: TTVQ tried operation: Nothing
# Day 28 Stock: Y5NS tried operation: Nothing
# Day 28 value: 1274.84
# Day 29 Stock: ZPVX tried operation: Buy
# Day 29 Stock: EJ0Y tried operation: Nothing
# Day 29 Stock: JHO0 tried operation: Buy
# Day 29 Stock: KCYU tried operation: Buy
# Day 29 Stock: TTVQ tried operation: Sell
# Day 29 Stock: Y5NS tried operation: Nothing
# Day 29 value: 1350.15
# Day 30 Stock: ZPVX tried operation: Buy
# Day 30 Stock: EJ0Y tried operation: Nothing
# Day 30 Stock: JHO0 tried operation: Buy
# Day 30 Stock: KCYU tried operation: Buy
# Day 30 Stock: TTVQ tried operation: Nothing
# Day 30 Stock: Y5NS tried operation: Nothing
# Day 30 value: 1429.93
# Day 31 Stock: ZPVX tried operation: Buy
# Day 31 Stock: EJ0Y tried operation: Nothing
# Day 31 Stock: JHO0 tried operation: Buy
# Day 31 Stock: KCYU tried operation: Buy
# Day 31 Stock: TTVQ tried operation: Nothing
# Day 31 Stock: Y5NS tried operation: Nothing
# Day 31 value: 1514.45
# Day 32 Stock: ZPVX tried operation: Buy
# Day 32 Stock: EJ0Y tried operation: Nothing
# Day 32 Stock: JHO0 tried operation: Buy
# Day 32 Stock: KCYU tried operation: Buy
# Day 32 Stock: TTVQ tried operation: Nothing
# Day 32 Stock: Y5NS tried operation: Nothing
# Day 32 value: 1603.98
# Day 33 Stock: ZPVX tried operation: Buy
# Day 33 Stock: EJ0Y tried operation: Nothing
# Day 33 Stock: JHO0 tried operation: Nothing
# Day 33 Stock: KCYU tried operation: Buy
# Day 33 Stock: TTVQ tried operation: Nothing
# Day 33 Stock: Y5NS tried operation: Nothing
# Day 33 value: 1698.82
# Day 34 Stock: ZPVX tried operation: Buy
# Day 34 Stock: EJ0Y tried operation: Nothing
# Day 34 Stock: JHO0 tried operation: Nothing
# Day 34 Stock: KCYU tried operation: Buy
# Day 34 Stock: TTVQ tried operation: Nothing
# Day 34 Stock: Y5NS tried operation: Nothing
# Day 34 value: 1663.16
# Day 35 Stock: ZPVX tried operation: Nothing
# Day 35 Stock: EJ0Y tried operation: Nothing
# Day 35 Stock: JHO0 tried operation: Nothing
# Day 35 Stock: KCYU tried operation: Buy
# Day 35 Stock: TTVQ tried operation: Nothing
# Day 35 Stock: Y5NS tried operation: Nothing
# Day 35 value: 1628.26
# Day 36 Stock: ZPVX tried operation: Nothing
# Day 36 Stock: EJ0Y tried operation: Nothing
# Day 36 Stock: JHO0 tried operation: Nothing
# Day 36 Stock: KCYU tried operation: Buy
# Day 36 Stock: TTVQ tried operation: Nothing
# Day 36 Stock: Y5NS tried operation: Nothing
# Day 36 value: 1619.79
# Day 37 Stock: ZPVX tried operation: Nothing
# Day 37 Stock: EJ0Y tried operation: Sell
# Day 37 Stock: JHO0 tried operation: Buy
# Day 37 Stock: KCYU tried operation: Nothing
# Day 37 Stock: TTVQ tried operation: Nothing
# Day 37 Stock: Y5NS tried operation: Sell
# Day 37 value: 1619.54
# Day 38 Stock: ZPVX tried operation: Nothing
# Day 38 Stock: EJ0Y tried operation: Sell
# Day 38 Stock: JHO0 tried operation: Buy
# Day 38 Stock: KCYU tried operation: Nothing
# Day 38 Stock: TTVQ tried operation: Nothing
# Day 38 Stock: Y5NS tried operation: Sell
# Day 38 value: 1619.29
# Day 39 Stock: ZPVX tried operation: Nothing
# Day 39 Stock: EJ0Y tried operation: Sell
# Day 39 Stock: JHO0 tried operation: Buy
# Day 39 Stock: KCYU tried operation: Nothing
# Day 39 Stock: TTVQ tried operation: Nothing
# Day 39 Stock: Y5NS tried operation: Nothing
# Day 39 value: 1619.03
# Day 40 Stock: ZPVX tried operation: Nothing
# Day 40 Stock: EJ0Y tried operation: Nothing
# Day 40 Stock: JHO0 tried operation: Buy
# Day 40 Stock: KCYU tried operation: Nothing
# Day 40 Stock: TTVQ tried operation: Nothing
# Day 40 Stock: Y5NS tried operation: Nothing
# Day 40 value: 1618.78
# Day 41 Stock: ZPVX tried operation: Nothing
# Day 41 Stock: EJ0Y tried operation: Nothing
# Day 41 Stock: JHO0 tried operation: Nothing
# Day 41 Stock: KCYU tried operation: Nothing
# Day 41 Stock: TTVQ tried operation: Nothing
# Day 41 Stock: Y5NS tried operation: Nothing
# Day 41 value: 1599.31
# Day 42 Stock: ZPVX tried operation: Nothing
# Day 42 Stock: EJ0Y tried operation: Nothing
# Day 42 Stock: JHO0 tried operation: Nothing
# Day 42 Stock: KCYU tried operation: Nothing
# Day 42 Stock: TTVQ tried operation: Nothing
# Day 42 Stock: Y5NS tried operation: Nothing
# Day 42 value: 1652.89
# Day 43 Stock: ZPVX tried operation: Buy
# Day 43 Stock: EJ0Y tried operation: Nothing
# Day 43 Stock: JHO0 tried operation: Nothing
# Day 43 Stock: KCYU tried operation: Nothing
# Day 43 Stock: TTVQ tried operation: Nothing
# Day 43 Stock: Y5NS tried operation: Nothing
# Day 43 value: 1708.26
# Day 44 Stock: ZPVX tried operation: Buy
# Day 44 Stock: EJ0Y tried operation: Nothing
# Day 44 Stock: JHO0 tried operation: Nothing
# Day 44 Stock: KCYU tried operation: Nothing
# Day 44 Stock: TTVQ tried operation: Nothing
# Day 44 Stock: Y5NS tried operation: Sell
# Day 44 value: 1825.03
# Day 45 Stock: ZPVX tried operation: Buy
# Day 45 Stock: EJ0Y tried operation: Nothing
# Day 45 Stock: JHO0 tried operation: Nothing
# Day 45 Stock: KCYU tried operation: Nothing
# Day 45 Stock: TTVQ tried operation: Nothing
# Day 45 Stock: Y5NS tried operation: Sell
# Day 45 value: 1949.80
# Day 46 Stock: ZPVX tried operation: Buy
# Day 46 Stock: EJ0Y tried operation: Nothing
# Day 46 Stock: JHO0 tried operation: Nothing
# Day 46 Stock: KCYU tried operation: Nothing
# Day 46 Stock: TTVQ tried operation: Nothing
# Day 46 Stock: Y5NS tried operation: Sell
# Day 46 value: 2083.13
# Day 47 Stock: ZPVX tried operation: Buy
# Day 47 Stock: EJ0Y tried operation: Sell
# Day 47 Stock: JHO0 tried operation: Buy
# Day 47 Stock: KCYU tried operation: Buy
# Day 47 Stock: TTVQ tried operation: Nothing
# Day 47 Stock: Y5NS tried operation: Sell
# Day 47 value: 2225.60
# Day 48 Stock: ZPVX tried operation: Buy
# Day 48 Stock: EJ0Y tried operation: Nothing
# Day 48 Stock: JHO0 tried operation: Buy
# Day 48 Stock: KCYU tried operation: Buy
# Day 48 Stock: TTVQ tried operation: Nothing
# Day 48 Stock: Y5NS tried operation: Nothing
# Day 48 value: 2176.52
# Day 49 Stock: ZPVX tried operation: Nothing
# Day 49 Stock: EJ0Y tried operation: Nothing
# Day 49 Stock: JHO0 tried operation: Buy
# Day 49 Stock: KCYU tried operation: Buy
# Day 49 Stock: TTVQ tried operation: Nothing
# Day 49 Stock: Y5NS tried operation: Nothing
# Day 49 value: 2128.53
# Day 50 Stock: ZPVX tried operation: Nothing
# Day 50 Stock: EJ0Y tried operation: Nothing
# Day 50 Stock: JHO0 tried operation: Buy
# Day 50 Stock: KCYU tried operation: Nothing
# Day 50 Stock: TTVQ tried operation: Nothing
# Day 50 Stock: Y5NS tried operation: Sell
# Day 50 value: 2081.59
# Day 51 Stock: ZPVX tried operation: Nothing
# Day 51 Stock: EJ0Y tried operation: Nothing
# Day 51 Stock: JHO0 tried operation: Buy
# Day 51 Stock: KCYU tried operation: Nothing
# Day 51 Stock: TTVQ tried operation: Nothing
# Day 51 Stock: Y5NS tried operation: Sell
# Day 51 value: 2035.70
# Day 52 Stock: ZPVX tried operation: Nothing
# Day 52 Stock: EJ0Y tried operation: Nothing
# Day 52 Stock: JHO0 tried operation: Nothing
# Day 52 Stock: KCYU tried operation: Nothing
# Day 52 Stock: TTVQ tried operation: Nothing
# Day 52 Stock: Y5NS tried operation: Sell
# Day 52 value: 1990.82
# Day 53 Stock: ZPVX tried operation: Nothing
# Day 53 Stock: EJ0Y tried operation: Nothing
# Day 53 Stock: JHO0 tried operation: Nothing
# Day 53 Stock: KCYU tried operation: Nothing
# Day 53 Stock: TTVQ tried operation: Nothing
# Day 53 Stock: Y5NS tried operation: Sell
# Day 53 value: 1956.97
# Day 54 Stock: ZPVX tried operation: Nothing
# Day 54 Stock: EJ0Y tried operation: Sell
# Day 54 Stock: JHO0 tried operation: Nothing
# Day 54 Stock: KCYU tried operation: Nothing
# Day 54 Stock: TTVQ tried operation: Nothing
# Day 54 Stock: Y5NS tried operation: Sell
# Day 54 value: 1923.69
# Day 55 Stock: ZPVX tried operation: Nothing
# Day 55 Stock: EJ0Y tried operation: Sell
# Day 55 Stock: JHO0 tried operation: Nothing
# Day 55 Stock: KCYU tried operation: Nothing
# Day 55 Stock: TTVQ tried operation: Nothing
# Day 55 Stock: Y5NS tried operation: Nothing
# Day 55 value: 1890.99
# Day 56 Stock: ZPVX tried operation: Nothing
# Day 56 Stock: EJ0Y tried operation: Sell
# Day 56 Stock: JHO0 tried operation: Nothing
# Day 56 Stock: KCYU tried operation: Nothing
# Day 56 Stock: TTVQ tried operation: Nothing
# Day 56 Stock: Y5NS tried operation: Nothing
# Day 56 value: 1858.84
# Day 57 Stock: ZPVX tried operation: Nothing
# Day 57 Stock: EJ0Y tried operation: Nothing
# Day 57 Stock: JHO0 tried operation: Nothing
# Day 57 Stock: KCYU tried operation: Nothing
# Day 57 Stock: TTVQ tried operation: Nothing
# Day 57 Stock: Y5NS tried operation: Nothing
# Day 57 value: 1820.33
# Day 58 Stock: ZPVX tried operation: Nothing
# Day 58 Stock: EJ0Y tried operation: Nothing
# Day 58 Stock: JHO0 tried operation: Nothing
# Day 58 Stock: KCYU tried operation: Nothing
# Day 58 Stock: TTVQ tried operation: Nothing
# Day 58 Stock: Y5NS tried operation: Nothing
# Day 58 value: 1782.63
# Day 59 Stock: ZPVX tried operation: Nothing
# Day 59 Stock: EJ0Y tried operation: Nothing
# Day 59 Stock: JHO0 tried operation: Nothing
# Day 59 Stock: KCYU tried operation: Nothing
# Day 59 Stock: TTVQ tried operation: Nothing
# Day 59 Stock: Y5NS tried operation: Nothing
# Day 59 value: 1835.39
# Day 60 Stock: ZPVX tried operation: Buy
# Day 60 Stock: EJ0Y tried operation: Nothing
# Day 60 Stock: JHO0 tried operation: Nothing
# Day 60 Stock: KCYU tried operation: Nothing
# Day 60 Stock: TTVQ tried operation: Nothing
# Day 60 Stock: Y5NS tried operation: Sell
# Day 60 value: 1889.72
# Day 61 Stock: ZPVX tried operation: Buy
# Day 61 Stock: EJ0Y tried operation: Nothing
# Day 61 Stock: JHO0 tried operation: Nothing
# Day 61 Stock: KCYU tried operation: Nothing
# Day 61 Stock: TTVQ tried operation: Nothing
# Day 61 Stock: Y5NS tried operation: Sell
# Day 61 value: 1945.67
# Day 62 Stock: ZPVX tried operation: Buy
# Day 62 Stock: EJ0Y tried operation: Nothing
# Day 62 Stock: JHO0 tried operation: Nothing
# Day 62 Stock: KCYU tried operation: Nothing
# Day 62 Stock: TTVQ tried operation: Nothing
# Day 62 Stock: Y5NS tried operation: Sell
# Day 62 value: 2003.27
# Day 63 Stock: ZPVX tried operation: Buy
# Day 63 Stock: EJ0Y tried operation: Nothing
# Day 63 Stock: JHO0 tried operation: Nothing
# Day 63 Stock: KCYU tried operation: Nothing
# Day 63 Stock: TTVQ tried operation: Nothing
# Day 63 Stock: Y5NS tried operation: Sell
# Day 63 value: 2090.30
# Day 64 Stock: ZPVX tried operation: Buy
# Day 64 Stock: EJ0Y tried operation: Nothing
# Day 64 Stock: JHO0 tried operation: Nothing
# Day 64 Stock: KCYU tried operation: Nothing
# Day 64 Stock: TTVQ tried operation: Nothing
# Day 64 Stock: Y5NS tried operation: Sell
# Day 64 value: 2113.98
# Day 65 Stock: ZPVX tried operation: Nothing
# Day 65 Stock: EJ0Y tried operation: Nothing
# Day 65 Stock: JHO0 tried operation: Nothing
# Day 65 Stock: KCYU tried operation: Nothing
# Day 65 Stock: TTVQ tried operation: Nothing
# Day 65 Stock: Y5NS tried operation: Nothing
# Day 65 value: 2137.93
# Day 66 Stock: ZPVX tried operation: Nothing
# Day 66 Stock: EJ0Y tried operation: Nothing
# Day 66 Stock: JHO0 tried operation: Nothing
# Day 66 Stock: KCYU tried operation: Nothing
# Day 66 Stock: TTVQ tried operation: Nothing
# Day 66 Stock: Y5NS tried operation: Nothing
# Day 66 value: 2162.16
# Day 67 Stock: ZPVX tried operation: Nothing
# Day 67 Stock: EJ0Y tried operation: Nothing
# Day 67 Stock: JHO0 tried operation: Nothing
# Day 67 Stock: KCYU tried operation: Buy
# Day 67 Stock: TTVQ tried operation: Nothing
# Day 67 Stock: Y5NS tried operation: Nothing
# Day 67 value: 2186.65
# Day 68 Stock: ZPVX tried operation: Nothing
# Day 68 Stock: EJ0Y tried operation: Nothing
# Day 68 Stock: JHO0 tried operation: Nothing
# Day 68 Stock: KCYU tried operation: Buy
# Day 68 Stock: TTVQ tried operation: Nothing
# Day 68 Stock: Y5NS tried operation: Nothing
# Day 68 value: 2211.43
# Day 69 Stock: ZPVX tried operation: Nothing
# Day 69 Stock: EJ0Y tried operation: Nothing
# Day 69 Stock: JHO0 tried operation: Nothing
# Day 69 Stock: KCYU tried operation: Nothing
# Day 69 Stock: TTVQ tried operation: Nothing
# Day 69 Stock: Y5NS tried operation: Sell
# Day 69 value: 2152.83
# Day 70 Stock: ZPVX tried operation: Nothing
# Day 70 Stock: EJ0Y tried operation: Nothing
# Day 70 Stock: JHO0 tried operation: Nothing
# Day 70 Stock: KCYU tried operation: Nothing
# Day 70 Stock: TTVQ tried operation: Nothing
# Day 70 Stock: Y5NS tried operation: Sell
# Day 70 value: 2095.78
# Day 71 Stock: ZPVX tried operation: Nothing
# Day 71 Stock: EJ0Y tried operation: Nothing
# Day 71 Stock: JHO0 tried operation: Nothing
# Day 71 Stock: KCYU tried operation: Nothing
# Day 71 Stock: TTVQ tried operation: Nothing
# Day 71 Stock: Y5NS tried operation: Sell
# Day 71 value: 2162.19
# Day 72 Stock: ZPVX tried operation: Buy
# Day 72 Stock: EJ0Y tried operation: Nothing
# Day 72 Stock: JHO0 tried operation: Nothing
# Day 72 Stock: KCYU tried operation: Nothing
# Day 72 Stock: TTVQ tried operation: Nothing
# Day 72 Stock: Y5NS tried operation: Sell
# Day 72 value: 2230.71
# Day 73 Stock: ZPVX tried operation: Buy
# Day 73 Stock: EJ0Y tried operation: Nothing
# Day 73 Stock: JHO0 tried operation: Nothing
# Day 73 Stock: KCYU tried operation: Nothing
# Day 73 Stock: TTVQ tried operation: Nothing
# Day 73 Stock: Y5NS tried operation: Sell
# Day 73 value: 2301.40
# Day 74 Stock: ZPVX tried operation: Buy
# Day 74 Stock: EJ0Y tried operation: Nothing
# Day 74 Stock: JHO0 tried operation: Nothing
# Day 74 Stock: KCYU tried operation: Nothing
# Day 74 Stock: TTVQ tried operation: Nothing
# Day 74 Stock: Y5NS tried operation: Sell
# Day 74 value: 2374.35
# Day 75 Stock: ZPVX tried operation: Buy
# Day 75 Stock: EJ0Y tried operation: Nothing
# Day 75 Stock: JHO0 tried operation: Nothing
# Day 75 Stock: KCYU tried operation: Nothing
# Day 75 Stock: TTVQ tried operation: Nothing
# Day 75 Stock: Y5NS tried operation: Sell
# Day 75 value: 2456.01
# Day 76 Stock: ZPVX tried operation: Nothing
# Day 76 Stock: EJ0Y tried operation: Nothing
# Day 76 Stock: JHO0 tried operation: Nothing
# Day 76 Stock: KCYU tried operation: Nothing
# Day 76 Stock: TTVQ tried operation: Nothing
# Day 76 Stock: Y5NS tried operation: Sell
# Day 76 value: 2540.48
# Day 77 Stock: ZPVX tried operation: Nothing
# Day 77 Stock: EJ0Y tried operation: Nothing
# Day 77 Stock: JHO0 tried operation: Nothing
# Day 77 Stock: KCYU tried operation: Nothing
# Day 77 Stock: TTVQ tried operation: Nothing
# Day 77 Stock: Y5NS tried operation: Nothing
# Day 77 value: 2627.87
# Day 78 Stock: ZPVX tried operation: Nothing
# Day 78 Stock: EJ0Y tried operation: Nothing
# Day 78 Stock: JHO0 tried operation: Nothing
# Day 78 Stock: KCYU tried operation: Nothing
# Day 78 Stock: TTVQ tried operation: Nothing
# Day 78 Stock: Y5NS tried operation: Nothing
# Day 78 value: 2718.27
# Day 79 Stock: ZPVX tried operation: Nothing
# Day 79 Stock: EJ0Y tried operation: Nothing
# Day 79 Stock: JHO0 tried operation: Nothing
# Day 79 Stock: KCYU tried operation: Nothing
# Day 79 Stock: TTVQ tried operation: Nothing
# Day 79 Stock: Y5NS tried operation: Nothing
# Day 79 value: 2811.79
# Day 80 Stock: ZPVX tried operation: Nothing
# Day 80 Stock: EJ0Y tried operation: Nothing
# Day 80 Stock: JHO0 tried operation: Nothing
# Day 80 Stock: KCYU tried operation: Nothing
# Day 80 Stock: TTVQ tried operation: Nothing
# Day 80 Stock: Y5NS tried operation: Nothing
# Day 80 value: 2908.53
# Day 81 Stock: ZPVX tried operation: Nothing
# Day 81 Stock: EJ0Y tried operation: Nothing
# Day 81 Stock: JHO0 tried operation: Buy
# Day 81 Stock: KCYU tried operation: Nothing
# Day 81 Stock: TTVQ tried operation: Nothing
# Day 81 Stock: Y5NS tried operation: Nothing
# Day 81 value: 3008.60
# Day 82 Stock: ZPVX tried operation: Nothing
# Day 82 Stock: EJ0Y tried operation: Nothing
# Day 82 Stock: JHO0 tried operation: Nothing
# Day 82 Stock: KCYU tried operation: Nothing
# Day 82 Stock: TTVQ tried operation: Nothing
# Day 82 Stock: Y5NS tried operation: Nothing
# Day 82 value: 3112.13
# Day 83 Stock: ZPVX tried operation: Nothing
# Day 83 Stock: EJ0Y tried operation: Nothing
# Day 83 Stock: JHO0 tried operation: Nothing
# Day 83 Stock: KCYU tried operation: Buy
# Day 83 Stock: TTVQ tried operation: Nothing
# Day 83 Stock: Y5NS tried operation: Sell
# Day 83 value: 3168.18
# Day 84 Stock: ZPVX tried operation: Nothing
# Day 84 Stock: EJ0Y tried operation: Nothing
# Day 84 Stock: JHO0 tried operation: Nothing
# Day 84 Stock: KCYU tried operation: Buy
# Day 84 Stock: TTVQ tried operation: Nothing
# Day 84 Stock: Y5NS tried operation: Sell
# Day 84 value: 3225.25
# Day 85 Stock: ZPVX tried operation: Nothing
# Day 85 Stock: EJ0Y tried operation: Nothing
# Day 85 Stock: JHO0 tried operation: Nothing
# Day 85 Stock: KCYU tried operation: Buy
# Day 85 Stock: TTVQ tried operation: Nothing
# Day 85 Stock: Y5NS tried operation: Nothing
# Day 85 value: 3283.34
# Day 86 Stock: ZPVX tried operation: Nothing
# Day 86 Stock: EJ0Y tried operation: Nothing
# Day 86 Stock: JHO0 tried operation: Nothing
# Day 86 Stock: KCYU tried operation: Nothing
# Day 86 Stock: TTVQ tried operation: Nothing
# Day 86 Stock: Y5NS tried operation: Nothing
# Day 86 value: 3342.48
# Day 87 Stock: ZPVX tried operation: Nothing
# Day 87 Stock: EJ0Y tried operation: Nothing
# Day 87 Stock: JHO0 tried operation: Nothing
# Day 87 Stock: KCYU tried operation: Nothing
# Day 87 Stock: TTVQ tried operation: Nothing
# Day 87 Stock: Y5NS tried operation: Nothing
# Day 87 value: 3402.69
# Day 88 Stock: ZPVX tried operation: Nothing
# Day 88 Stock: EJ0Y tried operation: Nothing
# Day 88 Stock: JHO0 tried operation: Nothing
# Day 88 Stock: KCYU tried operation: Nothing
# Day 88 Stock: TTVQ tried operation: Nothing
# Day 88 Stock: Y5NS tried operation: Nothing
# Day 88 value: 3463.98
# Day 89 Stock: ZPVX tried operation: Nothing
# Day 89 Stock: EJ0Y tried operation: Nothing
# Day 89 Stock: JHO0 tried operation: Nothing
# Day 89 Stock: KCYU tried operation: Nothing
# Day 89 Stock: TTVQ tried operation: Nothing
# Day 89 Stock: Y5NS tried operation: Nothing
# Day 89 value: 3399.29
# Day 90 Stock: ZPVX tried operation: Nothing
# Day 90 Stock: EJ0Y tried operation: Nothing
# Day 90 Stock: JHO0 tried operation: Nothing
# Day 90 Stock: KCYU tried operation: Nothing
# Day 90 Stock: TTVQ tried operation: Nothing
# Day 90 Stock: Y5NS tried operation: Nothing
# Day 90 value: 3335.81
# Day 91 Stock: ZPVX tried operation: Nothing
# Day 91 Stock: EJ0Y tried operation: Nothing
# Day 91 Stock: JHO0 tried operation: Nothing
# Day 91 Stock: KCYU tried operation: Nothing
# Day 91 Stock: TTVQ tried operation: Nothing
# Day 91 Stock: Y5NS tried operation: Nothing
# Day 91 value: 3273.52
# Day 92 Stock: ZPVX tried operation: Nothing
# Day 92 Stock: EJ0Y tried operation: Nothing
# Day 92 Stock: JHO0 tried operation: Nothing
# Day 92 Stock: KCYU tried operation: Nothing
# Day 92 Stock: TTVQ tried operation: Nothing
# Day 92 Stock: Y5NS tried operation: Nothing
# Day 92 value: 3212.39
# Day 93 Stock: ZPVX tried operation: Nothing
# Day 93 Stock: EJ0Y tried operation: Nothing
# Day 93 Stock: JHO0 tried operation: Nothing
# Day 93 Stock: KCYU tried operation: Nothing
# Day 93 Stock: TTVQ tried operation: Nothing
# Day 93 Stock: Y5NS tried operation: Nothing
# Day 93 value: 3119.47
# Day 94 Stock: ZPVX tried operation: Nothing
# Day 94 Stock: EJ0Y tried operation: Nothing
# Day 94 Stock: JHO0 tried operation: Buy
# Day 94 Stock: KCYU tried operation: Nothing
# Day 94 Stock: TTVQ tried operation: Nothing
# Day 94 Stock: Y5NS tried operation: Nothing
# Day 94 value: 3029.25
# Day 95 Stock: ZPVX tried operation: Nothing
# Day 95 Stock: EJ0Y tried operation: Nothing
# Day 95 Stock: JHO0 tried operation: Buy
# Day 95 Stock: KCYU tried operation: Nothing
# Day 95 Stock: TTVQ tried operation: Nothing
# Day 95 Stock: Y5NS tried operation: Nothing
# Day 95 value: 2941.64
# Day 96 Stock: ZPVX tried operation: Nothing
# Day 96 Stock: EJ0Y tried operation: Nothing
# Day 96 Stock: JHO0 tried operation: Nothing
# Day 96 Stock: KCYU tried operation: Nothing
# Day 96 Stock: TTVQ tried operation: Nothing
# Day 96 Stock: Y5NS tried operation: Nothing
# Day 96 value: 2856.57
# Day 97 Stock: ZPVX tried operation: Nothing
# Day 97 Stock: EJ0Y tried operation: Nothing
# Day 97 Stock: JHO0 tried operation: Nothing
# Day 97 Stock: KCYU tried operation: Nothing
# Day 97 Stock: TTVQ tried operation: Nothing
# Day 97 Stock: Y5NS tried operation: Nothing
# Day 97 value: 2773.97
# Day 98 Stock: ZPVX tried operation: Nothing
# Day 98 Stock: EJ0Y tried operation: Nothing
# Day 98 Stock: JHO0 tried operation: Nothing
# Day 98 Stock: KCYU tried operation: Nothing
# Day 98 Stock: TTVQ tried operation: Nothing
# Day 98 Stock: Y5NS tried operation: Nothing
# Day 98 value: 2709.34
# Day 99 Stock: ZPVX tried operation: Nothing
# Day 99 Stock: EJ0Y tried operation: Nothing
# Day 99 Stock: JHO0 tried operation: Nothing
# Day 99 Stock: KCYU tried operation: Nothing
# Day 99 Stock: TTVQ tried operation: Nothing
# Day 99 Stock: Y5NS tried operation: Nothing
# Day 99 value: 2666.93
# Day 100 Stock: ZPVX tried operation: Nothing
# Day 100 Stock: EJ0Y tried operation: Nothing
# Day 100 Stock: JHO0 tried operation: Nothing
# Day 100 Stock: KCYU tried operation: Nothing
# Day 100 Stock: TTVQ tried operation: Nothing
# Day 100 Stock: Y5NS tried operation: Nothing
# Day 100 value: 2625.19
#
#
# Total value of portfolio after 100 days: $2625.19

# %% [markdown]
# ## Sample Solution
