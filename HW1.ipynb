# %% [markdown]
# ## Homework Instruction: Stock Trading Simulation
#
# **Objective**: Use the concepts of Python you've learned in the last two lectures to design a simple stock trading algorithm. The goal is to maximize your money by the end of day 100.
#
# ### Description:
#
# 1. **StockMarket Class**:
#    - This class is provisws as-is. DO NOT modify this class.
#    - It has a method named `advance_one_day` which simulates the stock market for one day. If the price of a stock drops below $0.01, you will no longer be able to trade it, and the number of shares of that stock in your portfolio will become 0.
#    - It has a method named `get_stock_prices` which returns the current stock price.
#
# 2. **Portfolio Class**:
#    - This class is provisws as-is. DO NOT modify this class.
#    - **Attributes**:
#      - `cash`: the amount of money you currently have.
#      - `stocks`: number of different stocks you currently own.
#    - **Methods**:
#      - `buy`: purchase k shares of a given stock.
#        - Input: ticker of the stock (`stock_ticker`), number of shares (`k`), the current price of the given stock (`stock_price`).
#        - Deduct cash by `(stock price * k) + 0.50` (50 cents fee for each transaction).
#        - Update stocks attribute.
#      - `sell`: sell k shares of a stock.
#        - Input: ticker of the stock (`stock_ticker`), number of shares (`k`), the current price of the given stock (`stock_price`).
#        - Add to cash by `(stock price * k) - 0.50` (50 cents fee for each transaction).
#        - Update stocks attribute.
#
# 3. **Your Task**:
#    - For each day until day 100:
#      - Use `get_stock_prices` method to get the current stock prices.
#      - Decide whether to buy/sell stocks based on the current stock prices.
#      - Use `advance_one_day` method to move to the next day.
#    - You may write any helper functions you need, as long as you don't change the code of both classes.
#    - Your goal is to have as much money as possible by the end of day 100.
#
# **Steps**:
#
# 1. Initialize the stock market and your portfolio.
# 2. Loop through each day and make buy/sell decisions.
# 3. Use the `advance_one_day` function to progress through the simulation.
# 4. At the end of day 100, compute and print the total value (cash and stock values) of your portfolio.

# %% [markdown]
# ## Skeleton Code:

# %%
import numpy as np
import random
import string

class StockMarket:
    def __init__(self, stock_tickers):
        self.stock_prices = {ticker: np.random.uniform(10, 100) for ticker in stock_tickers}
        self.deltas = {ticker: self.get_new_delta() for ticker in stock_tickers}
        self.days_since_last_change = {ticker: 0 for ticker in stock_tickers}

    def get_new_delta(self):
        return np.random.normal(0, 0.03)

    def advance_one_day(self):
        for ticker in self.stock_prices:
            if self.stock_prices[ticker] < 0.01:
                continue
            chance_of_change = 0.1 + 0.1 * self.days_since_last_change[ticker]
            if np.random.rand() < chance_of_change:
                self.deltas[ticker] = self.get_new_delta()
                self.days_since_last_change[ticker] = 0
            self.stock_prices[ticker] *= (1 + self.deltas[ticker])
            self.days_since_last_change[ticker] += 1

    def get_stock_prices(self):
        return self.stock_prices

class Portfolio:
    def __init__(self, initial_cash):
        self.cash = initial_cash
        self.stocks = {}

    def buy(self, stock_ticker, k, stock_price):
        if stock_price < 0.01:
            self.stocks[stock_ticker] = 0
            return
        total_cost = (stock_price * k) + 0.50
        if self.cash >= total_cost:
            self.cash -= total_cost
            self.stocks[stock_ticker] = self.stocks.get(stock_ticker, 0) + k

    def sell(self, stock_ticker, k, stock_price):
        if stock_price < 0.01:
            self.stocks[stock_ticker] = 0
            return
        if stock_ticker in self.stocks and self.stocks[stock_ticker] >= k:
            self.cash += (stock_price * k) - 0.50
            self.stocks[stock_ticker] -= k
            if self.stocks[stock_ticker] == 0:
                del self.stocks[stock_ticker]

def generate_stock_ticker(length=4):
    """
    randomly generates a stock ticker containing upper case letters and numbers with the given length
    """
    letters = string.ascii_uppercase
    numbers = string.digits
    ticker = ''.join(random.choice(letters + numbers) for _ in range(length))
    return ticker

STOCK_TICKERS = [generate_stock_ticker() for _ in range(6)]
INITIAL_CASH = 1000


def main():
    ## TODO: Replace the following code with your algorithm
    final_value = 0
    
    # initilization
    my_portfolio = Portfolio(INITIAL_CASH)
    stock_market = StockMarket(STOCK_TICKERS)

    # keep track of stock prices
    stock_prices_lst = []

    for day in range(100):
        cur_stock_prices = stock_market.get_stock_prices()
    

        if day == 0:
            # copy dict to avoid using the same reference
            stock_prices_lst.append(cur_stock_prices.copy())
            stock_market.advance_one_day()
            continue

        yes_stock_prices = stock_prices_lst[-1]



        for stock_ticker in cur_stock_prices:
            cur_stock_price = cur_stock_prices[stock_ticker]
            yes_stock_price = yes_stock_prices[stock_ticker]

            delta = (cur_stock_price - yes_stock_price) / yes_stock_price

            if cur_stock_price <= 30 and delta >= 0.02:
                my_portfolio.buy(stock_ticker, 10 , cur_stock_price)
                print(f"Day {day+1} Stock: {stock_ticker} tried operation: Buy")
            elif cur_stock_price >= 70 and delta <= -0.01:
                my_portfolio.sell(stock_ticker, 10, cur_stock_price)
                print(f"Day {day+1} Stock: {stock_ticker} tried operation: Sell")
            else:
                print(f"Day {day+1} Stock: {stock_ticker} tried operation: Nothing")

        stock_prices_lst.append(cur_stock_prices.copy())
        stock_market.advance_one_day()

        final_value = my_portfolio.cash

        for stock_ticker, num_shares in my_portfolio.stocks.items():
            final_value += cur_stock_prices[stock_ticker] * num_shares
        
        print(f"Day {day+1} value: {final_value:.2f}")
        

    print('\n')
    print(f"Total value of portfolio after 100 days: ${final_value:.2f}")

if __name__ == "__main__":
    main()
# Out:
# Day 2 Stock: STT8 tried operation: Nothing
# Day 2 Stock: UF9J tried operation: Sell
# Day 2 Stock: KLNA tried operation: Nothing
# Day 2 Stock: D642 tried operation: Nothing
# Day 2 Stock: L9X8 tried operation: Nothing
# Day 2 Stock: A7OO tried operation: Sell
# Day 2 value: 1000.00
# Day 3 Stock: STT8 tried operation: Nothing
# Day 3 Stock: UF9J tried operation: Sell
# Day 3 Stock: KLNA tried operation: Nothing
# Day 3 Stock: D642 tried operation: Nothing
# Day 3 Stock: L9X8 tried operation: Nothing
# Day 3 Stock: A7OO tried operation: Sell
# Day 3 value: 1000.00
# Day 4 Stock: STT8 tried operation: Nothing
# Day 4 Stock: UF9J tried operation: Sell
# Day 4 Stock: KLNA tried operation: Nothing
# Day 4 Stock: D642 tried operation: Nothing
# Day 4 Stock: L9X8 tried operation: Nothing
# Day 4 Stock: A7OO tried operation: Sell
# Day 4 value: 1000.00
# Day 5 Stock: STT8 tried operation: Nothing
# Day 5 Stock: UF9J tried operation: Nothing
# Day 5 Stock: KLNA tried operation: Nothing
# Day 5 Stock: D642 tried operation: Nothing
# Day 5 Stock: L9X8 tried operation: Nothing
# Day 5 Stock: A7OO tried operation: Nothing
# Day 5 value: 1000.00
# Day 6 Stock: STT8 tried operation: Nothing
# Day 6 Stock: UF9J tried operation: Nothing
# Day 6 Stock: KLNA tried operation: Nothing
# Day 6 Stock: D642 tried operation: Nothing
# Day 6 Stock: L9X8 tried operation: Buy
# Day 6 Stock: A7OO tried operation: Nothing
# Day 6 value: 1009.73
# Day 7 Stock: STT8 tried operation: Nothing
# Day 7 Stock: UF9J tried operation: Nothing
# Day 7 Stock: KLNA tried operation: Nothing
# Day 7 Stock: D642 tried operation: Nothing
# Day 7 Stock: L9X8 tried operation: Buy
# Day 7 Stock: A7OO tried operation: Nothing
# Day 7 value: 1031.05
# Day 8 Stock: STT8 tried operation: Nothing
# Day 8 Stock: UF9J tried operation: Nothing
# Day 8 Stock: KLNA tried operation: Nothing
# Day 8 Stock: D642 tried operation: Buy
# Day 8 Stock: L9X8 tried operation: Buy
# Day 8 Stock: A7OO tried operation: Nothing
# Day 8 value: 1070.51
# Day 9 Stock: STT8 tried operation: Nothing
# Day 9 Stock: UF9J tried operation: Nothing
# Day 9 Stock: KLNA tried operation: Nothing
# Day 9 Stock: D642 tried operation: Buy
# Day 9 Stock: L9X8 tried operation: Buy
# Day 9 Stock: A7OO tried operation: Nothing
# Day 9 value: 1110.57
# Day 10 Stock: STT8 tried operation: Nothing
# Day 10 Stock: UF9J tried operation: Nothing
# Day 10 Stock: KLNA tried operation: Nothing
# Day 10 Stock: D642 tried operation: Nothing
# Day 10 Stock: L9X8 tried operation: Buy
# Day 10 Stock: A7OO tried operation: Nothing
# Day 10 value: 1114.63
# Day 11 Stock: STT8 tried operation: Nothing
# Day 11 Stock: UF9J tried operation: Sell
# Day 11 Stock: KLNA tried operation: Nothing
# Day 11 Stock: D642 tried operation: Nothing
# Day 11 Stock: L9X8 tried operation: Nothing
# Day 11 Stock: A7OO tried operation: Nothing
# Day 11 value: 1135.81
# Day 12 Stock: STT8 tried operation: Nothing
# Day 12 Stock: UF9J tried operation: Sell
# Day 12 Stock: KLNA tried operation: Nothing
# Day 12 Stock: D642 tried operation: Buy
# Day 12 Stock: L9X8 tried operation: Nothing
# Day 12 Stock: A7OO tried operation: Nothing
# Day 12 value: 1145.07
# Day 13 Stock: STT8 tried operation: Nothing
# Day 13 Stock: UF9J tried operation: Sell
# Day 13 Stock: KLNA tried operation: Nothing
# Day 13 Stock: D642 tried operation: Buy
# Day 13 Stock: L9X8 tried operation: Nothing
# Day 13 Stock: A7OO tried operation: Nothing
# Day 13 value: 1148.57
# Day 14 Stock: STT8 tried operation: Nothing
# Day 14 Stock: UF9J tried operation: Nothing
# Day 14 Stock: KLNA tried operation: Nothing
# Day 14 Stock: D642 tried operation: Buy
# Day 14 Stock: L9X8 tried operation: Nothing
# Day 14 Stock: A7OO tried operation: Nothing
# Day 14 value: 1159.90
# Day 15 Stock: STT8 tried operation: Nothing
# Day 15 Stock: UF9J tried operation: Nothing
# Day 15 Stock: KLNA tried operation: Nothing
# Day 15 Stock: D642 tried operation: Buy
# Day 15 Stock: L9X8 tried operation: Nothing
# Day 15 Stock: A7OO tried operation: Nothing
# Day 15 value: 1172.18
# Day 16 Stock: STT8 tried operation: Nothing
# Day 16 Stock: UF9J tried operation: Nothing
# Day 16 Stock: KLNA tried operation: Nothing
# Day 16 Stock: D642 tried operation: Buy
# Day 16 Stock: L9X8 tried operation: Nothing
# Day 16 Stock: A7OO tried operation: Nothing
# Day 16 value: 1185.46
# Day 17 Stock: STT8 tried operation: Nothing
# Day 17 Stock: UF9J tried operation: Nothing
# Day 17 Stock: KLNA tried operation: Nothing
# Day 17 Stock: D642 tried operation: Buy
# Day 17 Stock: L9X8 tried operation: Nothing
# Day 17 Stock: A7OO tried operation: Nothing
# Day 17 value: 1165.58
# Day 18 Stock: STT8 tried operation: Nothing
# Day 18 Stock: UF9J tried operation: Nothing
# Day 18 Stock: KLNA tried operation: Nothing
# Day 18 Stock: D642 tried operation: Buy
# Day 18 Stock: L9X8 tried operation: Nothing
# Day 18 Stock: A7OO tried operation: Nothing
# Day 18 value: 1103.21
# Day 19 Stock: STT8 tried operation: Nothing
# Day 19 Stock: UF9J tried operation: Nothing
# Day 19 Stock: KLNA tried operation: Nothing
# Day 19 Stock: D642 tried operation: Nothing
# Day 19 Stock: L9X8 tried operation: Nothing
# Day 19 Stock: A7OO tried operation: Nothing
# Day 19 value: 1108.19
# Day 20 Stock: STT8 tried operation: Nothing
# Day 20 Stock: UF9J tried operation: Nothing
# Day 20 Stock: KLNA tried operation: Nothing
# Day 20 Stock: D642 tried operation: Nothing
# Day 20 Stock: L9X8 tried operation: Nothing
# Day 20 Stock: A7OO tried operation: Nothing
# Day 20 value: 1113.21
# Day 21 Stock: STT8 tried operation: Nothing
# Day 21 Stock: UF9J tried operation: Sell
# Day 21 Stock: KLNA tried operation: Nothing
# Day 21 Stock: D642 tried operation: Nothing
# Day 21 Stock: L9X8 tried operation: Nothing
# Day 21 Stock: A7OO tried operation: Nothing
# Day 21 value: 1118.27
# Day 22 Stock: STT8 tried operation: Nothing
# Day 22 Stock: UF9J tried operation: Sell
# Day 22 Stock: KLNA tried operation: Nothing
# Day 22 Stock: D642 tried operation: Nothing
# Day 22 Stock: L9X8 tried operation: Nothing
# Day 22 Stock: A7OO tried operation: Nothing
# Day 22 value: 1123.37
# Day 23 Stock: STT8 tried operation: Nothing
# Day 23 Stock: UF9J tried operation: Sell
# Day 23 Stock: KLNA tried operation: Nothing
# Day 23 Stock: D642 tried operation: Nothing
# Day 23 Stock: L9X8 tried operation: Nothing
# Day 23 Stock: A7OO tried operation: Nothing
# Day 23 value: 1114.87
# Day 24 Stock: STT8 tried operation: Nothing
# Day 24 Stock: UF9J tried operation: Sell
# Day 24 Stock: KLNA tried operation: Nothing
# Day 24 Stock: D642 tried operation: Nothing
# Day 24 Stock: L9X8 tried operation: Buy
# Day 24 Stock: A7OO tried operation: Nothing
# Day 24 value: 1108.73
# Day 25 Stock: STT8 tried operation: Nothing
# Day 25 Stock: UF9J tried operation: Nothing
# Day 25 Stock: KLNA tried operation: Nothing
# Day 25 Stock: D642 tried operation: Nothing
# Day 25 Stock: L9X8 tried operation: Buy
# Day 25 Stock: A7OO tried operation: Nothing
# Day 25 value: 1104.83
# Day 26 Stock: STT8 tried operation: Nothing
# Day 26 Stock: UF9J tried operation: Nothing
# Day 26 Stock: KLNA tried operation: Nothing
# Day 26 Stock: D642 tried operation: Nothing
# Day 26 Stock: L9X8 tried operation: Buy
# Day 26 Stock: A7OO tried operation: Nothing
# Day 26 value: 1103.05
# Day 27 Stock: STT8 tried operation: Nothing
# Day 27 Stock: UF9J tried operation: Nothing
# Day 27 Stock: KLNA tried operation: Nothing
# Day 27 Stock: D642 tried operation: Nothing
# Day 27 Stock: L9X8 tried operation: Buy
# Day 27 Stock: A7OO tried operation: Nothing
# Day 27 value: 1121.42
# Day 28 Stock: STT8 tried operation: Nothing
# Day 28 Stock: UF9J tried operation: Sell
# Day 28 Stock: KLNA tried operation: Nothing
# Day 28 Stock: D642 tried operation: Nothing
# Day 28 Stock: L9X8 tried operation: Buy
# Day 28 Stock: A7OO tried operation: Nothing
# Day 28 value: 1143.04
# Day 29 Stock: STT8 tried operation: Nothing
# Day 29 Stock: UF9J tried operation: Sell
# Day 29 Stock: KLNA tried operation: Nothing
# Day 29 Stock: D642 tried operation: Nothing
# Day 29 Stock: L9X8 tried operation: Buy
# Day 29 Stock: A7OO tried operation: Nothing
# Day 29 value: 1183.05
# Day 30 Stock: STT8 tried operation: Nothing
# Day 30 Stock: UF9J tried operation: Sell
# Day 30 Stock: KLNA tried operation: Nothing
# Day 30 Stock: D642 tried operation: Nothing
# Day 30 Stock: L9X8 tried operation: Buy
# Day 30 Stock: A7OO tried operation: Nothing
# Day 30 value: 1225.08
# Day 31 Stock: STT8 tried operation: Nothing
# Day 31 Stock: UF9J tried operation: Nothing
# Day 31 Stock: KLNA tried operation: Nothing
# Day 31 Stock: D642 tried operation: Nothing
# Day 31 Stock: L9X8 tried operation: Buy
# Day 31 Stock: A7OO tried operation: Nothing
# Day 31 value: 1269.24
# Day 32 Stock: STT8 tried operation: Sell
# Day 32 Stock: UF9J tried operation: Nothing
# Day 32 Stock: KLNA tried operation: Nothing
# Day 32 Stock: D642 tried operation: Nothing
# Day 32 Stock: L9X8 tried operation: Buy
# Day 32 Stock: A7OO tried operation: Nothing
# Day 32 value: 1302.23
# Day 33 Stock: STT8 tried operation: Sell
# Day 33 Stock: UF9J tried operation: Nothing
# Day 33 Stock: KLNA tried operation: Nothing
# Day 33 Stock: D642 tried operation: Nothing
# Day 33 Stock: L9X8 tried operation: Buy
# Day 33 Stock: A7OO tried operation: Nothing
# Day 33 value: 1336.45
# Day 34 Stock: STT8 tried operation: Nothing
# Day 34 Stock: UF9J tried operation: Nothing
# Day 34 Stock: KLNA tried operation: Sell
# Day 34 Stock: D642 tried operation: Nothing
# Day 34 Stock: L9X8 tried operation: Buy
# Day 34 Stock: A7OO tried operation: Nothing
# Day 34 value: 1324.35
# Day 35 Stock: STT8 tried operation: Nothing
# Day 35 Stock: UF9J tried operation: Nothing
# Day 35 Stock: KLNA tried operation: Sell
# Day 35 Stock: D642 tried operation: Nothing
# Day 35 Stock: L9X8 tried operation: Nothing
# Day 35 Stock: A7OO tried operation: Nothing
# Day 35 value: 1312.40
# Day 36 Stock: STT8 tried operation: Nothing
# Day 36 Stock: UF9J tried operation: Nothing
# Day 36 Stock: KLNA tried operation: Sell
# Day 36 Stock: D642 tried operation: Nothing
# Day 36 Stock: L9X8 tried operation: Nothing
# Day 36 Stock: A7OO tried operation: Nothing
# Day 36 value: 1312.97
# Day 37 Stock: STT8 tried operation: Nothing
# Day 37 Stock: UF9J tried operation: Nothing
# Day 37 Stock: KLNA tried operation: Sell
# Day 37 Stock: D642 tried operation: Buy
# Day 37 Stock: L9X8 tried operation: Nothing
# Day 37 Stock: A7OO tried operation: Nothing
# Day 37 value: 1313.89
# Day 38 Stock: STT8 tried operation: Nothing
# Day 38 Stock: UF9J tried operation: Nothing
# Day 38 Stock: KLNA tried operation: Sell
# Day 38 Stock: D642 tried operation: Buy
# Day 38 Stock: L9X8 tried operation: Nothing
# Day 38 Stock: A7OO tried operation: Nothing
# Day 38 value: 1315.15
# Day 39 Stock: STT8 tried operation: Sell
# Day 39 Stock: UF9J tried operation: Nothing
# Day 39 Stock: KLNA tried operation: Sell
# Day 39 Stock: D642 tried operation: Buy
# Day 39 Stock: L9X8 tried operation: Nothing
# Day 39 Stock: A7OO tried operation: Nothing
# Day 39 value: 1354.64
# Day 40 Stock: STT8 tried operation: Sell
# Day 40 Stock: UF9J tried operation: Nothing
# Day 40 Stock: KLNA tried operation: Sell
# Day 40 Stock: D642 tried operation: Nothing
# Day 40 Stock: L9X8 tried operation: Buy
# Day 40 Stock: A7OO tried operation: Nothing
# Day 40 value: 1385.37
# Day 41 Stock: STT8 tried operation: Sell
# Day 41 Stock: UF9J tried operation: Nothing
# Day 41 Stock: KLNA tried operation: Nothing
# Day 41 Stock: D642 tried operation: Nothing
# Day 41 Stock: L9X8 tried operation: Buy
# Day 41 Stock: A7OO tried operation: Nothing
# Day 41 value: 1417.66
# Day 42 Stock: STT8 tried operation: Sell
# Day 42 Stock: UF9J tried operation: Nothing
# Day 42 Stock: KLNA tried operation: Nothing
# Day 42 Stock: D642 tried operation: Nothing
# Day 42 Stock: L9X8 tried operation: Buy
# Day 42 Stock: A7OO tried operation: Nothing
# Day 42 value: 1453.31
# Day 43 Stock: STT8 tried operation: Nothing
# Day 43 Stock: UF9J tried operation: Nothing
# Day 43 Stock: KLNA tried operation: Nothing
# Day 43 Stock: D642 tried operation: Nothing
# Day 43 Stock: L9X8 tried operation: Buy
# Day 43 Stock: A7OO tried operation: Nothing
# Day 43 value: 1414.28
# Day 44 Stock: STT8 tried operation: Nothing
# Day 44 Stock: UF9J tried operation: Nothing
# Day 44 Stock: KLNA tried operation: Nothing
# Day 44 Stock: D642 tried operation: Nothing
# Day 44 Stock: L9X8 tried operation: Nothing
# Day 44 Stock: A7OO tried operation: Nothing
# Day 44 value: 1371.03
# Day 45 Stock: STT8 tried operation: Nothing
# Day 45 Stock: UF9J tried operation: Nothing
# Day 45 Stock: KLNA tried operation: Nothing
# Day 45 Stock: D642 tried operation: Nothing
# Day 45 Stock: L9X8 tried operation: Nothing
# Day 45 Stock: A7OO tried operation: Nothing
# Day 45 value: 1329.16
# Day 46 Stock: STT8 tried operation: Sell
# Day 46 Stock: UF9J tried operation: Nothing
# Day 46 Stock: KLNA tried operation: Nothing
# Day 46 Stock: D642 tried operation: Nothing
# Day 46 Stock: L9X8 tried operation: Nothing
# Day 46 Stock: A7OO tried operation: Nothing
# Day 46 value: 1288.62
# Day 47 Stock: STT8 tried operation: Sell
# Day 47 Stock: UF9J tried operation: Nothing
# Day 47 Stock: KLNA tried operation: Nothing
# Day 47 Stock: D642 tried operation: Nothing
# Day 47 Stock: L9X8 tried operation: Nothing
# Day 47 Stock: A7OO tried operation: Nothing
# Day 47 value: 1249.37
# Day 48 Stock: STT8 tried operation: Nothing
# Day 48 Stock: UF9J tried operation: Nothing
# Day 48 Stock: KLNA tried operation: Nothing
# Day 48 Stock: D642 tried operation: Nothing
# Day 48 Stock: L9X8 tried operation: Nothing
# Day 48 Stock: A7OO tried operation: Nothing
# Day 48 value: 1282.61
# Day 49 Stock: STT8 tried operation: Nothing
# Day 49 Stock: UF9J tried operation: Nothing
# Day 49 Stock: KLNA tried operation: Nothing
# Day 49 Stock: D642 tried operation: Nothing
# Day 49 Stock: L9X8 tried operation: Buy
# Day 49 Stock: A7OO tried operation: Nothing
# Day 49 value: 1316.68
# Day 50 Stock: STT8 tried operation: Nothing
# Day 50 Stock: UF9J tried operation: Nothing
# Day 50 Stock: KLNA tried operation: Nothing
# Day 50 Stock: D642 tried operation: Nothing
# Day 50 Stock: L9X8 tried operation: Buy
# Day 50 Stock: A7OO tried operation: Nothing
# Day 50 value: 1348.26
# Day 51 Stock: STT8 tried operation: Nothing
# Day 51 Stock: UF9J tried operation: Nothing
# Day 51 Stock: KLNA tried operation: Nothing
# Day 51 Stock: D642 tried operation: Nothing
# Day 51 Stock: L9X8 tried operation: Buy
# Day 51 Stock: A7OO tried operation: Sell
# Day 51 value: 1345.69
# Day 52 Stock: STT8 tried operation: Nothing
# Day 52 Stock: UF9J tried operation: Nothing
# Day 52 Stock: KLNA tried operation: Nothing
# Day 52 Stock: D642 tried operation: Nothing
# Day 52 Stock: L9X8 tried operation: Nothing
# Day 52 Stock: A7OO tried operation: Sell
# Day 52 value: 1343.57
# Day 53 Stock: STT8 tried operation: Nothing
# Day 53 Stock: UF9J tried operation: Nothing
# Day 53 Stock: KLNA tried operation: Nothing
# Day 53 Stock: D642 tried operation: Nothing
# Day 53 Stock: L9X8 tried operation: Nothing
# Day 53 Stock: A7OO tried operation: Sell
# Day 53 value: 1345.13
# Day 54 Stock: STT8 tried operation: Sell
# Day 54 Stock: UF9J tried operation: Nothing
# Day 54 Stock: KLNA tried operation: Nothing
# Day 54 Stock: D642 tried operation: Nothing
# Day 54 Stock: L9X8 tried operation: Nothing
# Day 54 Stock: A7OO tried operation: Sell
# Day 54 value: 1346.84
# Day 55 Stock: STT8 tried operation: Nothing
# Day 55 Stock: UF9J tried operation: Nothing
# Day 55 Stock: KLNA tried operation: Nothing
# Day 55 Stock: D642 tried operation: Nothing
# Day 55 Stock: L9X8 tried operation: Nothing
# Day 55 Stock: A7OO tried operation: Sell
# Day 55 value: 1335.56
# Day 56 Stock: STT8 tried operation: Nothing
# Day 56 Stock: UF9J tried operation: Nothing
# Day 56 Stock: KLNA tried operation: Nothing
# Day 56 Stock: D642 tried operation: Nothing
# Day 56 Stock: L9X8 tried operation: Nothing
# Day 56 Stock: A7OO tried operation: Nothing
# Day 56 value: 1349.50
# Day 57 Stock: STT8 tried operation: Sell
# Day 57 Stock: UF9J tried operation: Nothing
# Day 57 Stock: KLNA tried operation: Nothing
# Day 57 Stock: D642 tried operation: Nothing
# Day 57 Stock: L9X8 tried operation: Nothing
# Day 57 Stock: A7OO tried operation: Nothing
# Day 57 value: 1361.87
# Day 58 Stock: STT8 tried operation: Sell
# Day 58 Stock: UF9J tried operation: Nothing
# Day 58 Stock: KLNA tried operation: Nothing
# Day 58 Stock: D642 tried operation: Nothing
# Day 58 Stock: L9X8 tried operation: Nothing
# Day 58 Stock: A7OO tried operation: Nothing
# Day 58 value: 1381.79
# Day 59 Stock: STT8 tried operation: Nothing
# Day 59 Stock: UF9J tried operation: Nothing
# Day 59 Stock: KLNA tried operation: Nothing
# Day 59 Stock: D642 tried operation: Nothing
# Day 59 Stock: L9X8 tried operation: Nothing
# Day 59 Stock: A7OO tried operation: Nothing
# Day 59 value: 1402.08
# Day 60 Stock: STT8 tried operation: Nothing
# Day 60 Stock: UF9J tried operation: Nothing
# Day 60 Stock: KLNA tried operation: Nothing
# Day 60 Stock: D642 tried operation: Nothing
# Day 60 Stock: L9X8 tried operation: Nothing
# Day 60 Stock: A7OO tried operation: Nothing
# Day 60 value: 1422.73
# Day 61 Stock: STT8 tried operation: Sell
# Day 61 Stock: UF9J tried operation: Nothing
# Day 61 Stock: KLNA tried operation: Nothing
# Day 61 Stock: D642 tried operation: Nothing
# Day 61 Stock: L9X8 tried operation: Nothing
# Day 61 Stock: A7OO tried operation: Nothing
# Day 61 value: 1443.76
# Day 62 Stock: STT8 tried operation: Sell
# Day 62 Stock: UF9J tried operation: Nothing
# Day 62 Stock: KLNA tried operation: Nothing
# Day 62 Stock: D642 tried operation: Nothing
# Day 62 Stock: L9X8 tried operation: Nothing
# Day 62 Stock: A7OO tried operation: Sell
# Day 62 value: 1518.21
# Day 63 Stock: STT8 tried operation: Sell
# Day 63 Stock: UF9J tried operation: Nothing
# Day 63 Stock: KLNA tried operation: Nothing
# Day 63 Stock: D642 tried operation: Nothing
# Day 63 Stock: L9X8 tried operation: Nothing
# Day 63 Stock: A7OO tried operation: Sell
# Day 63 value: 1597.63
# Day 64 Stock: STT8 tried operation: Sell
# Day 64 Stock: UF9J tried operation: Nothing
# Day 64 Stock: KLNA tried operation: Nothing
# Day 64 Stock: D642 tried operation: Nothing
# Day 64 Stock: L9X8 tried operation: Nothing
# Day 64 Stock: A7OO tried operation: Sell
# Day 64 value: 1677.88
# Day 65 Stock: STT8 tried operation: Sell
# Day 65 Stock: UF9J tried operation: Nothing
# Day 65 Stock: KLNA tried operation: Nothing
# Day 65 Stock: D642 tried operation: Nothing
# Day 65 Stock: L9X8 tried operation: Nothing
# Day 65 Stock: A7OO tried operation: Sell
# Day 65 value: 1668.94
# Day 66 Stock: STT8 tried operation: Nothing
# Day 66 Stock: UF9J tried operation: Nothing
# Day 66 Stock: KLNA tried operation: Nothing
# Day 66 Stock: D642 tried operation: Nothing
# Day 66 Stock: L9X8 tried operation: Nothing
# Day 66 Stock: A7OO tried operation: Sell
# Day 66 value: 1686.50
# Day 67 Stock: STT8 tried operation: Nothing
# Day 67 Stock: UF9J tried operation: Nothing
# Day 67 Stock: KLNA tried operation: Nothing
# Day 67 Stock: D642 tried operation: Nothing
# Day 67 Stock: L9X8 tried operation: Nothing
# Day 67 Stock: A7OO tried operation: Sell
# Day 67 value: 1709.72
# Day 68 Stock: STT8 tried operation: Nothing
# Day 68 Stock: UF9J tried operation: Nothing
# Day 68 Stock: KLNA tried operation: Nothing
# Day 68 Stock: D642 tried operation: Nothing
# Day 68 Stock: L9X8 tried operation: Nothing
# Day 68 Stock: A7OO tried operation: Sell
# Day 68 value: 1733.87
# Day 69 Stock: STT8 tried operation: Nothing
# Day 69 Stock: UF9J tried operation: Nothing
# Day 69 Stock: KLNA tried operation: Nothing
# Day 69 Stock: D642 tried operation: Nothing
# Day 69 Stock: L9X8 tried operation: Nothing
# Day 69 Stock: A7OO tried operation: Sell
# Day 69 value: 1763.04
# Day 70 Stock: STT8 tried operation: Nothing
# Day 70 Stock: UF9J tried operation: Nothing
# Day 70 Stock: KLNA tried operation: Nothing
# Day 70 Stock: D642 tried operation: Buy
# Day 70 Stock: L9X8 tried operation: Nothing
# Day 70 Stock: A7OO tried operation: Nothing
# Day 70 value: 1792.73
# Day 71 Stock: STT8 tried operation: Nothing
# Day 71 Stock: UF9J tried operation: Nothing
# Day 71 Stock: KLNA tried operation: Nothing
# Day 71 Stock: D642 tried operation: Buy
# Day 71 Stock: L9X8 tried operation: Nothing
# Day 71 Stock: A7OO tried operation: Nothing
# Day 71 value: 1810.14
# Day 72 Stock: STT8 tried operation: Nothing
# Day 72 Stock: UF9J tried operation: Nothing
# Day 72 Stock: KLNA tried operation: Nothing
# Day 72 Stock: D642 tried operation: Nothing
# Day 72 Stock: L9X8 tried operation: Nothing
# Day 72 Stock: A7OO tried operation: Sell
# Day 72 value: 1887.35
# Day 73 Stock: STT8 tried operation: Nothing
# Day 73 Stock: UF9J tried operation: Nothing
# Day 73 Stock: KLNA tried operation: Nothing
# Day 73 Stock: D642 tried operation: Nothing
# Day 73 Stock: L9X8 tried operation: Nothing
# Day 73 Stock: A7OO tried operation: Nothing
# Day 73 value: 1968.52
# Day 74 Stock: STT8 tried operation: Nothing
# Day 74 Stock: UF9J tried operation: Nothing
# Day 74 Stock: KLNA tried operation: Nothing
# Day 74 Stock: D642 tried operation: Nothing
# Day 74 Stock: L9X8 tried operation: Nothing
# Day 74 Stock: A7OO tried operation: Nothing
# Day 74 value: 1992.56
# Day 75 Stock: STT8 tried operation: Nothing
# Day 75 Stock: UF9J tried operation: Nothing
# Day 75 Stock: KLNA tried operation: Nothing
# Day 75 Stock: D642 tried operation: Nothing
# Day 75 Stock: L9X8 tried operation: Nothing
# Day 75 Stock: A7OO tried operation: Nothing
# Day 75 value: 2017.20
# Day 76 Stock: STT8 tried operation: Nothing
# Day 76 Stock: UF9J tried operation: Nothing
# Day 76 Stock: KLNA tried operation: Nothing
# Day 76 Stock: D642 tried operation: Nothing
# Day 76 Stock: L9X8 tried operation: Nothing
# Day 76 Stock: A7OO tried operation: Nothing
# Day 76 value: 2043.61
# Day 77 Stock: STT8 tried operation: Nothing
# Day 77 Stock: UF9J tried operation: Nothing
# Day 77 Stock: KLNA tried operation: Nothing
# Day 77 Stock: D642 tried operation: Nothing
# Day 77 Stock: L9X8 tried operation: Nothing
# Day 77 Stock: A7OO tried operation: Nothing
# Day 77 value: 2070.54
# Day 78 Stock: STT8 tried operation: Nothing
# Day 78 Stock: UF9J tried operation: Nothing
# Day 78 Stock: KLNA tried operation: Nothing
# Day 78 Stock: D642 tried operation: Nothing
# Day 78 Stock: L9X8 tried operation: Nothing
# Day 78 Stock: A7OO tried operation: Nothing
# Day 78 value: 2098.00
# Day 79 Stock: STT8 tried operation: Nothing
# Day 79 Stock: UF9J tried operation: Nothing
# Day 79 Stock: KLNA tried operation: Nothing
# Day 79 Stock: D642 tried operation: Nothing
# Day 79 Stock: L9X8 tried operation: Nothing
# Day 79 Stock: A7OO tried operation: Nothing
# Day 79 value: 2098.93
# Day 80 Stock: STT8 tried operation: Nothing
# Day 80 Stock: UF9J tried operation: Nothing
# Day 80 Stock: KLNA tried operation: Nothing
# Day 80 Stock: D642 tried operation: Nothing
# Day 80 Stock: L9X8 tried operation: Nothing
# Day 80 Stock: A7OO tried operation: Nothing
# Day 80 value: 1935.77
# Day 81 Stock: STT8 tried operation: Sell
# Day 81 Stock: UF9J tried operation: Nothing
# Day 81 Stock: KLNA tried operation: Nothing
# Day 81 Stock: D642 tried operation: Nothing
# Day 81 Stock: L9X8 tried operation: Nothing
# Day 81 Stock: A7OO tried operation: Nothing
# Day 81 value: 1785.87
# Day 82 Stock: STT8 tried operation: Sell
# Day 82 Stock: UF9J tried operation: Nothing
# Day 82 Stock: KLNA tried operation: Nothing
# Day 82 Stock: D642 tried operation: Nothing
# Day 82 Stock: L9X8 tried operation: Nothing
# Day 82 Stock: A7OO tried operation: Nothing
# Day 82 value: 1684.00
# Day 83 Stock: STT8 tried operation: Nothing
# Day 83 Stock: UF9J tried operation: Nothing
# Day 83 Stock: KLNA tried operation: Nothing
# Day 83 Stock: D642 tried operation: Nothing
# Day 83 Stock: L9X8 tried operation: Nothing
# Day 83 Stock: A7OO tried operation: Sell
# Day 83 value: 1588.25
# Day 84 Stock: STT8 tried operation: Nothing
# Day 84 Stock: UF9J tried operation: Nothing
# Day 84 Stock: KLNA tried operation: Nothing
# Day 84 Stock: D642 tried operation: Nothing
# Day 84 Stock: L9X8 tried operation: Nothing
# Day 84 Stock: A7OO tried operation: Sell
# Day 84 value: 1619.14
# Day 85 Stock: STT8 tried operation: Nothing
# Day 85 Stock: UF9J tried operation: Nothing
# Day 85 Stock: KLNA tried operation: Nothing
# Day 85 Stock: D642 tried operation: Nothing
# Day 85 Stock: L9X8 tried operation: Nothing
# Day 85 Stock: A7OO tried operation: Sell
# Day 85 value: 1650.72
# Day 86 Stock: STT8 tried operation: Sell
# Day 86 Stock: UF9J tried operation: Nothing
# Day 86 Stock: KLNA tried operation: Nothing
# Day 86 Stock: D642 tried operation: Nothing
# Day 86 Stock: L9X8 tried operation: Nothing
# Day 86 Stock: A7OO tried operation: Sell
# Day 86 value: 1682.98
# Day 87 Stock: STT8 tried operation: Sell
# Day 87 Stock: UF9J tried operation: Nothing
# Day 87 Stock: KLNA tried operation: Nothing
# Day 87 Stock: D642 tried operation: Nothing
# Day 87 Stock: L9X8 tried operation: Nothing
# Day 87 Stock: A7OO tried operation: Sell
# Day 87 value: 1714.92
# Day 88 Stock: STT8 tried operation: Sell
# Day 88 Stock: UF9J tried operation: Nothing
# Day 88 Stock: KLNA tried operation: Nothing
# Day 88 Stock: D642 tried operation: Nothing
# Day 88 Stock: L9X8 tried operation: Nothing
# Day 88 Stock: A7OO tried operation: Sell
# Day 88 value: 1741.82
# Day 89 Stock: STT8 tried operation: Sell
# Day 89 Stock: UF9J tried operation: Nothing
# Day 89 Stock: KLNA tried operation: Nothing
# Day 89 Stock: D642 tried operation: Nothing
# Day 89 Stock: L9X8 tried operation: Nothing
# Day 89 Stock: A7OO tried operation: Sell
# Day 89 value: 1769.27
# Day 90 Stock: STT8 tried operation: Sell
# Day 90 Stock: UF9J tried operation: Nothing
# Day 90 Stock: KLNA tried operation: Nothing
# Day 90 Stock: D642 tried operation: Nothing
# Day 90 Stock: L9X8 tried operation: Nothing
# Day 90 Stock: A7OO tried operation: Nothing
# Day 90 value: 1795.96
# Day 91 Stock: STT8 tried operation: Sell
# Day 91 Stock: UF9J tried operation: Nothing
# Day 91 Stock: KLNA tried operation: Nothing
# Day 91 Stock: D642 tried operation: Nothing
# Day 91 Stock: L9X8 tried operation: Nothing
# Day 91 Stock: A7OO tried operation: Nothing
# Day 91 value: 1828.05
# Day 92 Stock: STT8 tried operation: Sell
# Day 92 Stock: UF9J tried operation: Nothing
# Day 92 Stock: KLNA tried operation: Nothing
# Day 92 Stock: D642 tried operation: Buy
# Day 92 Stock: L9X8 tried operation: Nothing
# Day 92 Stock: A7OO tried operation: Nothing
# Day 92 value: 1877.13
# Day 93 Stock: STT8 tried operation: Sell
# Day 93 Stock: UF9J tried operation: Nothing
# Day 93 Stock: KLNA tried operation: Nothing
# Day 93 Stock: D642 tried operation: Buy
# Day 93 Stock: L9X8 tried operation: Nothing
# Day 93 Stock: A7OO tried operation: Sell
# Day 93 value: 1927.54
# Day 94 Stock: STT8 tried operation: Sell
# Day 94 Stock: UF9J tried operation: Nothing
# Day 94 Stock: KLNA tried operation: Nothing
# Day 94 Stock: D642 tried operation: Buy
# Day 94 Stock: L9X8 tried operation: Nothing
# Day 94 Stock: A7OO tried operation: Sell
# Day 94 value: 1975.25
# Day 95 Stock: STT8 tried operation: Sell
# Day 95 Stock: UF9J tried operation: Nothing
# Day 95 Stock: KLNA tried operation: Nothing
# Day 95 Stock: D642 tried operation: Nothing
# Day 95 Stock: L9X8 tried operation: Nothing
# Day 95 Stock: A7OO tried operation: Sell
# Day 95 value: 2024.85
# Day 96 Stock: STT8 tried operation: Nothing
# Day 96 Stock: UF9J tried operation: Nothing
# Day 96 Stock: KLNA tried operation: Nothing
# Day 96 Stock: D642 tried operation: Nothing
# Day 96 Stock: L9X8 tried operation: Nothing
# Day 96 Stock: A7OO tried operation: Sell
# Day 96 value: 1900.14
# Day 97 Stock: STT8 tried operation: Nothing
# Day 97 Stock: UF9J tried operation: Nothing
# Day 97 Stock: KLNA tried operation: Nothing
# Day 97 Stock: D642 tried operation: Buy
# Day 97 Stock: L9X8 tried operation: Nothing
# Day 97 Stock: A7OO tried operation: Sell
# Day 97 value: 1784.04
# Day 98 Stock: STT8 tried operation: Nothing
# Day 98 Stock: UF9J tried operation: Nothing
# Day 98 Stock: KLNA tried operation: Nothing
# Day 98 Stock: D642 tried operation: Buy
# Day 98 Stock: L9X8 tried operation: Nothing
# Day 98 Stock: A7OO tried operation: Nothing
# Day 98 value: 1675.99
# Day 99 Stock: STT8 tried operation: Nothing
# Day 99 Stock: UF9J tried operation: Nothing
# Day 99 Stock: KLNA tried operation: Nothing
# Day 99 Stock: D642 tried operation: Buy
# Day 99 Stock: L9X8 tried operation: Nothing
# Day 99 Stock: A7OO tried operation: Nothing
# Day 99 value: 1722.70
# Day 100 Stock: STT8 tried operation: Nothing
# Day 100 Stock: UF9J tried operation: Nothing
# Day 100 Stock: KLNA tried operation: Nothing
# Day 100 Stock: D642 tried operation: Nothing
# Day 100 Stock: L9X8 tried operation: Nothing
# Day 100 Stock: A7OO tried operation: Nothing
# Day 100 value: 1770.90
#
#
# Total value of portfolio after 100 days: $1770.90

# %% [markdown]
# ## Sample Solution
